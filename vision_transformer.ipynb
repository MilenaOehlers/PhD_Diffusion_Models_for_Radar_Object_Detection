# %% [markdown]
# <a href="https://colab.research.google.com/github/MilenaOehlers/generative_models_for_deep_radar_object_detection/blob/main/vision_transformer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Following https://medium.com/@brianpulfer/vision-transformers-from-scratch-pytorch-a-step-by-step-guide-96c3313c2e0c

# %%
import numpy as np

from tqdm import tqdm, trange

import torch
import torch.nn as nn
from torch.optim import Adam
from torch.nn import CrossEntropyLoss
from torch.utils.data import DataLoader

from torchvision.transforms import ToTensor
from torchvision.datasets.mnist import MNIST

np.random.seed(0)
torch.manual_seed(0)

# %%
class MyMSA(nn.Module):
    def __init__(self, d, n_heads=2):
        super(MyMSA, self).__init__()
        self.d = d
        self.n_heads = n_heads

        assert d%n_heads==0, f"Can't divide dimension {d} into {n_heads} heads"

        d_head = int(d / n_heads)
        """Wait... so here, as opposed to the regular transformer tutorial,
         not d_model==d is the dimension of q_mappings,
        but d_head?? In that case, applying weights to both K and Q truely
        does not make sense. """
        self.q_mappings = nn.ModuleList([nn.Linear(d_head, d_head) for _ in range(self.n_heads)])
        self.k_mappings = nn.ModuleList([nn.Linear(d_head, d_head) for _ in range(self.n_heads)])
        self.v_mappings = nn.ModuleList([nn.Linear(d_head, d_head) for _ in range(self.n_heads)])
        self.d_head = d_head
        self.softmax = nn.Softmax(dim=-1)

    def forward(self, sequences):
        # Sequences has shape (N, seq_length, token_dim)
        # We go into shape    (N, seq_length, n_heads, token_dim / n_heads)
        # And come back to    (N, seq_length, item_dim)  (through concatenation)
        result = []

        """In tutorial: 'Also notice that using loops is not the most efficient
        way to compute the multi-head self-attention, but it makes the code much
        clearer for learning.'"""
        for sequence in sequences:
            seq_result = []
            for head in range(self.n_heads):
                q_mapping = self.q_mappings[head]
                k_mapping = self.k_mappings[head]
                v_mapping = self.v_mappings[head]

                """
                So, of each picture, we have 49 patches of original size 16 but
                encoded size token_dim==8, and of those 8dims, eg. 4x (2 belong
                to one head only), hence its as if instead of 8 dims we had (2x4) dims,
                with n_channels=n_heads=4; very same, just different way of writing.

                So, P pictures of 49 patches each with n_pixels==16 each.
                each picture-patch combi is converted independently, but in the
                very same way, via learnable parameters into basically a
                (n_heads x d_head) presentation.

                Inside each head, head_specific K/Q/V matrices are applied
                and only inside-head matrix multiplication takes place.

                So yes, both Q and K weighing makes no sense.
                """
                seq = sequence[:, head * self.d_head: (head + 1) * self.d_head]
                # q, k, and v have dim (n_patches x d_head)
                q, k, v = q_mapping(seq), k_mapping(seq), v_mapping(seq)

                # attention hence has dim (n_patches x n_patches)
                attention = self.softmax(q @ k.T / (self.d_head ** 0.5))
                # appended partial result has dim (n_patches x d_head) again
                seq_result.append(attention @ v)
            result.append(torch.hstack(seq_result)) # -> n_patches x token_dim
        # torch.cat default dim==0, so stack pictures back onto each other:
        return torch.cat([torch.unsqueeze(r, dim=0) for r in result])

# %%
class MyViTBlock(nn.Module):
    def __init__(self, hidden_d, n_heads, mlp_ratio=4):
        super(MyViTBlock, self).__init__()
        self.hidden_d = hidden_d
        self.n_heads = n_heads

        self.norm1 = nn.LayerNorm(hidden_d)
        self.mhsa = MyMSA(hidden_d, n_heads)
        self.norm2 = nn.LayerNorm(hidden_d)
        # Multi-Layer-Perceptron:
        self.mlp = nn.Sequential(
            nn.Linear(hidden_d, mlp_ratio * hidden_d),
            nn.GELU(),
            nn.Linear(mlp_ratio * hidden_d, hidden_d)
        )

    def forward(self, x):
        out = x + self.mhsa(self.norm1(x))
        out = out + self.mlp(self.norm2(out))
        return out

# %%
class MyViT(nn.Module):
  def __init__(self, chw=(1, 28, 28), n_patches=7, n_blocks=2,  hidden_d=8,
               n_heads=2, out_d=10):
    # Super constructor
    super(MyViT, self).__init__()

    # Attributes
    self.chw = chw # (C, H, W)
    self.n_patches = n_patches
    self.hidden_d = hidden_d

    assert chw[1] % n_patches == 0, "Input shape not entirely divisible by number of patches"
    assert chw[2] % n_patches == 0, "Input shape not entirely divisible by number of patches"
    self.patch_size = (chw[1] / n_patches, chw[2] / n_patches)

    # 1) Linear mapper
    self.input_d = int(chw[0] * self.patch_size[0] * self.patch_size[1])
    self.linear_mapper = nn.Linear(self.input_d, self.hidden_d)

    # 2) Learnable classifiation token
    self.class_token = nn.Parameter(torch.rand(1, self.hidden_d))

    # 3) Positional embedding
    self.pos_embed = nn.Parameter(torch.tensor(self.get_positional_embeddings(self.n_patches ** 2 + 1, self.hidden_d)))
    self.pos_embed.requires_grad = False

    # 4) Transformer encoder blocks
    self.blocks = nn.ModuleList([MyViTBlock(hidden_d, n_heads) for _ in range(n_blocks)])

    # 5) Classification MLPk
    self.mlp = nn.Sequential(
        nn.Linear(self.hidden_d, out_d),
        nn.Softmax(dim=-1)
    )
    """
    nn.LayerNorm: normalizes over last D dimensions of the input tensor,
    e.g. layer_norm = nn.LayerNorm([49,16])
    for our N pictures, each constisting of 49 patches of 4*4 pixels,
    hence forming an input tensor of (N,49,16)
    """

  def forward(self, images):
    patches = self.patchify(images, self.n_patches)
    tokens = self.linear_mapper(patches)

    # Adding classification token to the tokens
    tokens = torch.stack([torch.vstack((self.class_token, tokens[i]))
                          for i in range(len(tokens))])

    # Adding positional embedding
    pos_embed = self.pos_embed.repeat(images.shape[0], 1, 1)
    out = tokens + pos_embed

    # Transformer Blocks
    for block in self.blocks:
        out = block(out)

    # Getting the classification token only
    out = out[:, 0]

    return self.mlp(out) # Map to output dimension, output category distribution

  def patchify(self,images, n_patches):
    n, c, h, w = images.shape

    assert h == w, "Patchify method is implemented for square images only"

    patches = torch.zeros(n, n_patches ** 2, h * w * c // n_patches ** 2)
    patch_size = h // n_patches

    for idx, image in enumerate(images):
        for i in range(n_patches):
            for j in range(n_patches):
                patch = image[:, i * patch_size: (i + 1) * patch_size, j * patch_size: (j + 1) * patch_size]
                patches[idx, i * n_patches + j] = patch.flatten()
    return patches

  def get_positional_embeddings(self, sequence_length, d):
    result = torch.ones(sequence_length, d)
    for i in range(sequence_length):
        for j in range(d):
            result[i][j] = np.sin(i / (10000 ** (j / d))) if j % 2 == 0 else np.cos(i / (10000 ** ((j - 1) / d)))
    return result

# %%
def main():
    # Loading data
    transform = ToTensor()

    train_set = MNIST(root='./../datasets', train=True, download=True, transform=transform)
    test_set = MNIST(root='./../datasets', train=False, download=True, transform=transform)

    train_loader = DataLoader(train_set, shuffle=True, batch_size=128)
    test_loader = DataLoader(test_set, shuffle=False, batch_size=128)

    # Defining model and training options
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    print("Using device: ", device, f"({torch.cuda.get_device_name(device)})" if torch.cuda.is_available() else "")
    model = MyViT((1, 28, 28), n_patches=7, n_blocks=2, hidden_d=8, n_heads=2, out_d=10).to(device)
    N_EPOCHS = 5
    LR = 0.005

    # Training loop
    """Somehow weird to me that the training loop has to be written explicitly,
    with setting gradients to zero manually... surely, torch provides a whole
    automatic fucntionality for that? """
    optimizer = Adam(model.parameters(), lr=LR)
    criterion = CrossEntropyLoss()
    for epoch in trange(N_EPOCHS, desc="Training"):
        train_loss = 0.0
        for batch in tqdm(train_loader, desc=f"Epoch {epoch + 1} in training", leave=False):
            x, y = batch
            x, y = x.to(device), y.to(device)
            y_hat = model(x)
            loss = criterion(y_hat, y)

            """ not sure why in the following / len(train_loader)?
            is a loss always supposed to be an average per-batch loss?
            Or maybe the len(train_loader)==n_training, not n_batches.
            Then, would make much more sense!
            -> but here, it actually returns n_batches. bit weird to me, but ok
            """
            train_loss += loss.detach().cpu().item() / len(train_loader)

            """Why would the gradient be set to zero after each batch??
            -> accoring to https://pytorch.org/tutorials/recipes/recipes/zeroing_out_gradients.html
            gradients are accumulated in buffers whenever .backward()
            is called during calculation, and not overwritten
            If were not interested in testing for vanishing or exploding gradients
            afterwards, we can delete them, or zero them out.
            Actually, even in the explicit example provided there, they zero out
            the gradients inside each epoch>batch loop.

            So, it seems gradients have to be zeroed out before accumulating
            gradients in the derivate graph leaves again, as else the gradients
            from last calculation would be added to the ones of this calculation
            hence overshooting, (= applying the wrong gradients), correct or not?

            I am still surprised that these elements are coded this explicitly
            if I remember correctly, inside tensorflow that was taken care of?
            """

            optimizer.zero_grad() # override gradients in buffer with zero
            loss.backward() # accumulate gradients into the leaves
            optimizer.step() # parameter upgrade based on accum. gradients

        print(f"Epoch {epoch + 1}/{N_EPOCHS} loss: {train_loss:.2f}")

    # Test loop
    with torch.no_grad():
        correct, total = 0, 0
        test_loss = 0.0
        for batch in tqdm(test_loader, desc="Testing"):
            x, y = batch
            x, y = x.to(device), y.to(device)
            y_hat = model(x)
            loss = criterion(y_hat, y)
            test_loss += loss.detach().cpu().item() / len(test_loader)

            correct += torch.sum(torch.argmax(y_hat, dim=1) == y).detach().cpu().item()
            total += len(x)
        print(f"Test loss: {test_loss:.2f}")
        print(f"Test accuracy: {correct / total * 100:.2f}%")

# %%
main()
# Out:
# <ipython-input-26-477bed6cf123>:24: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.pos_embed = nn.Parameter(torch.tensor(self.get_positional_embeddings(self.n_patches ** 2 + 1, self.hidden_d)))
# Using device:  cpu
# Training:   0%|          | 0/5 [00:00<?, ?it/s]
# Epoch 1 in training:   0%|          | 0/469 [00:00<?, ?it/s]
# Epoch 1 in training:   0%|          | 1/469 [00:00<06:38,  1.17it/s]
# Epoch 1 in training:   0%|          | 2/469 [00:01<04:52,  1.60it/s]
# Epoch 1 in training:   1%|          | 3/469 [00:01<04:19,  1.79it/s]
# Epoch 1 in training:   1%|          | 4/469 [00:02<03:59,  1.94it/s]
# Epoch 1 in training:   1%|          | 5/469 [00:02<03:52,  2.00it/s]
# Epoch 1 in training:   1%|▏         | 6/469 [00:03<03:43,  2.08it/s]
# Epoch 1 in training:   1%|▏         | 7/469 [00:03<03:38,  2.12it/s]
# Epoch 1 in training:   2%|▏         | 8/469 [00:04<03:37,  2.12it/s]
# Epoch 1 in training:   2%|▏         | 9/469 [00:04<03:35,  2.13it/s]
# Epoch 1 in training:   2%|▏         | 10/469 [00:05<03:34,  2.14it/s]
# Epoch 1 in training:   2%|▏         | 11/469 [00:05<03:31,  2.17it/s]
# Epoch 1 in training:   3%|▎         | 12/469 [00:05<03:30,  2.17it/s]
# Epoch 1 in training:   3%|▎         | 13/469 [00:06<03:27,  2.20it/s]
# Epoch 1 in training:   3%|▎         | 14/469 [00:06<03:28,  2.19it/s]
# Epoch 1 in training:   3%|▎         | 15/469 [00:07<03:26,  2.20it/s]
# Epoch 1 in training:   3%|▎         | 16/469 [00:07<03:24,  2.21it/s]
# Epoch 1 in training:   4%|▎         | 17/469 [00:08<03:24,  2.21it/s]
# Epoch 1 in training:   4%|▍         | 18/469 [00:08<03:23,  2.22it/s]
# Epoch 1 in training:   4%|▍         | 19/469 [00:09<03:23,  2.21it/s]
# Epoch 1 in training:   4%|▍         | 20/469 [00:09<03:22,  2.22it/s]
# Epoch 1 in training:   4%|▍         | 21/469 [00:09<03:23,  2.20it/s]
# Epoch 1 in training:   5%|▍         | 22/469 [00:10<03:23,  2.19it/s]
# Epoch 1 in training:   5%|▍         | 23/469 [00:10<03:30,  2.12it/s]
# Epoch 1 in training:   5%|▌         | 24/469 [00:11<03:56,  1.88it/s]
# Epoch 1 in training:   5%|▌         | 25/469 [00:12<04:12,  1.76it/s]
# Epoch 1 in training:   6%|▌         | 26/469 [00:13<04:33,  1.62it/s]
# Epoch 1 in training:   6%|▌         | 27/469 [00:13<04:22,  1.69it/s]
# Epoch 1 in training:   6%|▌         | 28/469 [00:13<04:01,  1.82it/s]
# Epoch 1 in training:   6%|▌         | 29/469 [00:14<03:49,  1.92it/s]
# Epoch 1 in training:   6%|▋         | 30/469 [00:14<03:39,  2.00it/s]
# Epoch 1 in training:   7%|▋         | 31/469 [00:15<03:35,  2.03it/s]
# Epoch 1 in training:   7%|▋         | 32/469 [00:15<03:30,  2.08it/s]
# Epoch 1 in training:   7%|▋         | 33/469 [00:16<03:26,  2.11it/s]
# Epoch 1 in training:   7%|▋         | 34/469 [00:16<03:23,  2.13it/s]
# Epoch 1 in training:   7%|▋         | 35/469 [00:17<03:23,  2.13it/s]
# Epoch 1 in training:   8%|▊         | 36/469 [00:17<03:21,  2.15it/s]
# Epoch 1 in training:   8%|▊         | 37/469 [00:18<03:45,  1.92it/s]
# Epoch 1 in training:   8%|▊         | 38/469 [00:18<03:38,  1.97it/s]
# Epoch 1 in training:   8%|▊         | 39/469 [00:19<03:33,  2.01it/s]
# Epoch 1 in training:   9%|▊         | 40/469 [00:19<03:28,  2.06it/s]
# Epoch 1 in training:   9%|▊         | 41/469 [00:20<03:23,  2.10it/s]
# Epoch 1 in training:   9%|▉         | 42/469 [00:20<03:24,  2.09it/s]
# Epoch 1 in training:   9%|▉         | 43/469 [00:21<03:22,  2.11it/s]
# Epoch 1 in training:   9%|▉         | 44/469 [00:21<03:21,  2.11it/s]
# Epoch 1 in training:  10%|▉         | 45/469 [00:22<03:18,  2.13it/s]
# Epoch 1 in training:  10%|▉         | 46/469 [00:22<03:17,  2.14it/s]
# Epoch 1 in training:  10%|█         | 47/469 [00:22<03:15,  2.16it/s]
# Epoch 1 in training:  10%|█         | 48/469 [00:23<03:28,  2.02it/s]
# Epoch 1 in training:  10%|█         | 49/469 [00:24<03:48,  1.84it/s]
# Epoch 1 in training:  11%|█         | 50/469 [00:24<04:05,  1.70it/s]
# Epoch 1 in training:  11%|█         | 51/469 [00:25<04:27,  1.56it/s]
# Epoch 1 in training:  11%|█         | 52/469 [00:26<04:03,  1.71it/s]
# Epoch 1 in training:  11%|█▏        | 53/469 [00:26<03:48,  1.82it/s]
# Epoch 1 in training:  12%|█▏        | 54/469 [00:27<03:38,  1.90it/s]
# Epoch 1 in training:  12%|█▏        | 55/469 [00:27<03:33,  1.94it/s]
# Epoch 1 in training:  12%|█▏        | 56/469 [00:28<03:25,  2.01it/s]
# Epoch 1 in training:  12%|█▏        | 57/469 [00:28<03:51,  1.78it/s]
# Epoch 1 in training:  12%|█▏        | 58/469 [00:29<03:35,  1.91it/s]
# Epoch 1 in training:  13%|█▎        | 59/469 [00:29<03:58,  1.72it/s]
# Epoch 1 in training:  13%|█▎        | 60/469 [00:30<04:09,  1.64it/s]
# Epoch 1 in training:  13%|█▎        | 61/469 [00:31<03:50,  1.77it/s]
# Epoch 1 in training:  13%|█▎        | 62/469 [00:31<03:39,  1.85it/s]
# Epoch 1 in training:  13%|█▎        | 63/469 [00:31<03:29,  1.94it/s]
# Epoch 1 in training:  14%|█▎        | 64/469 [00:32<03:21,  2.01it/s]
# Epoch 1 in training:  14%|█▍        | 65/469 [00:32<03:18,  2.03it/s]
# Epoch 1 in training:  14%|█▍        | 66/469 [00:33<03:12,  2.09it/s]
# Epoch 1 in training:  14%|█▍        | 67/469 [00:33<03:10,  2.11it/s]
# Epoch 1 in training:  14%|█▍        | 68/469 [00:34<03:06,  2.15it/s]
# Epoch 1 in training:  15%|█▍        | 69/469 [00:34<03:04,  2.17it/s]
# Epoch 1 in training:  15%|█▍        | 70/469 [00:35<03:04,  2.16it/s]
# Epoch 1 in training:  15%|█▌        | 71/469 [00:35<03:03,  2.16it/s]
# Epoch 1 in training:  15%|█▌        | 72/469 [00:36<03:28,  1.90it/s]
# Epoch 1 in training:  16%|█▌        | 73/469 [00:36<03:45,  1.75it/s]
# Epoch 1 in training:  16%|█▌        | 74/469 [00:37<04:01,  1.64it/s]
# Epoch 1 in training:  16%|█▌        | 75/469 [00:38<03:58,  1.65it/s]
# Epoch 1 in training:  16%|█▌        | 76/469 [00:38<03:39,  1.79it/s]
# Epoch 1 in training:  16%|█▋        | 77/469 [00:39<03:27,  1.89it/s]
# Epoch 1 in training:  17%|█▋        | 78/469 [00:39<03:18,  1.97it/s]
# Epoch 1 in training:  17%|█▋        | 79/469 [00:40<03:13,  2.02it/s]
# Epoch 1 in training:  17%|█▋        | 80/469 [00:40<03:08,  2.06it/s]
# Epoch 1 in training:  17%|█▋        | 81/469 [00:41<03:06,  2.08it/s]
# Epoch 1 in training:  17%|█▋        | 82/469 [00:41<03:03,  2.11it/s]
# Epoch 1 in training:  18%|█▊        | 83/469 [00:41<03:00,  2.14it/s]
# Epoch 1 in training:  18%|█▊        | 84/469 [00:42<02:59,  2.15it/s]
# Epoch 1 in training:  18%|█▊        | 85/469 [00:42<02:58,  2.15it/s]
# Epoch 1 in training:  18%|█▊        | 86/469 [00:43<02:58,  2.15it/s]
# Epoch 1 in training:  19%|█▊        | 87/469 [00:43<02:55,  2.17it/s]
# Epoch 1 in training:  19%|█▉        | 88/469 [00:44<02:56,  2.16it/s]
# Epoch 1 in training:  19%|█▉        | 89/469 [00:44<02:55,  2.16it/s]
# Epoch 1 in training:  19%|█▉        | 90/469 [00:45<02:55,  2.16it/s]
# Epoch 1 in training:  19%|█▉        | 91/469 [00:45<02:54,  2.17it/s]
# Epoch 1 in training:  20%|█▉        | 92/469 [00:46<02:53,  2.18it/s]
# Epoch 1 in training:  20%|█▉        | 93/469 [00:46<02:53,  2.16it/s]
# Epoch 1 in training:  20%|██        | 94/469 [00:47<02:53,  2.17it/s]
# Epoch 1 in training:  20%|██        | 95/469 [00:47<02:54,  2.14it/s]
# Epoch 1 in training:  20%|██        | 96/469 [00:47<02:54,  2.14it/s]
# Epoch 1 in training:  21%|██        | 97/469 [00:48<03:18,  1.88it/s]
# Epoch 1 in training:  21%|██        | 98/469 [00:49<03:33,  1.74it/s]
# Epoch 1 in training:  21%|██        | 99/469 [00:50<03:48,  1.62it/s]
# Epoch 1 in training:  21%|██▏       | 100/469 [00:50<03:50,  1.60it/s]
# Epoch 1 in training:  22%|██▏       | 101/469 [00:51<03:31,  1.74it/s]
# Epoch 1 in training:  22%|██▏       | 102/469 [00:51<03:21,  1.82it/s]
# Epoch 1 in training:  22%|██▏       | 103/469 [00:52<03:12,  1.90it/s]
# Epoch 1 in training:  22%|██▏       | 104/469 [00:52<03:08,  1.94it/s]
# Epoch 1 in training:  22%|██▏       | 105/469 [00:53<03:01,  2.00it/s]
# Epoch 1 in training:  23%|██▎       | 106/469 [00:53<02:58,  2.04it/s]
# Epoch 1 in training:  23%|██▎       | 107/469 [00:53<02:55,  2.06it/s]
# Epoch 1 in training:  23%|██▎       | 108/469 [00:54<02:54,  2.07it/s]
# Epoch 1 in training:  23%|██▎       | 109/469 [00:54<02:55,  2.05it/s]
# Epoch 1 in training:  23%|██▎       | 110/469 [00:55<02:53,  2.06it/s]
# Epoch 1 in training:  24%|██▎       | 111/469 [00:55<02:55,  2.04it/s]
# Epoch 1 in training:  24%|██▍       | 112/469 [00:56<02:53,  2.06it/s]
# Epoch 1 in training:  24%|██▍       | 113/469 [00:56<02:52,  2.06it/s]
# Epoch 1 in training:  24%|██▍       | 114/469 [00:57<02:51,  2.07it/s]
# Epoch 1 in training:  25%|██▍       | 115/469 [00:57<02:53,  2.04it/s]
# Epoch 1 in training:  25%|██▍       | 116/469 [00:58<02:52,  2.05it/s]
# Epoch 1 in training:  25%|██▍       | 117/469 [00:58<02:52,  2.04it/s]
# Epoch 1 in training:  25%|██▌       | 118/469 [00:59<02:50,  2.06it/s]
# Epoch 1 in training:  25%|██▌       | 119/469 [00:59<02:49,  2.07it/s]
# Epoch 1 in training:  26%|██▌       | 120/469 [01:00<02:46,  2.09it/s]
# Epoch 1 in training:  26%|██▌       | 121/469 [01:00<03:05,  1.88it/s]
# Epoch 1 in training:  26%|██▌       | 122/469 [01:01<03:20,  1.73it/s]
# Epoch 1 in training:  26%|██▌       | 123/469 [01:02<03:41,  1.57it/s]
# Epoch 1 in training:  26%|██▋       | 124/469 [01:03<03:43,  1.55it/s]
# Epoch 1 in training:  27%|██▋       | 125/469 [01:03<03:26,  1.67it/s]
# Epoch 1 in training:  27%|██▋       | 126/469 [01:04<03:13,  1.77it/s]
# Epoch 1 in training:  27%|██▋       | 127/469 [01:04<03:04,  1.85it/s]
# Epoch 1 in training:  27%|██▋       | 128/469 [01:05<03:00,  1.89it/s]
# Epoch 1 in training:  28%|██▊       | 129/469 [01:05<02:52,  1.97it/s]
# Epoch 1 in training:  28%|██▊       | 130/469 [01:05<02:48,  2.01it/s]
# Epoch 1 in training:  28%|██▊       | 131/469 [01:06<02:44,  2.06it/s]
# Epoch 1 in training:  28%|██▊       | 132/469 [01:06<02:41,  2.09it/s]
# Epoch 1 in training:  28%|██▊       | 133/469 [01:07<02:39,  2.10it/s]
# Epoch 1 in training:  29%|██▊       | 134/469 [01:07<02:37,  2.13it/s]
# Epoch 1 in training:  29%|██▉       | 135/469 [01:08<02:36,  2.14it/s]
# Epoch 1 in training:  29%|██▉       | 136/469 [01:08<02:34,  2.16it/s]
# Epoch 1 in training:  29%|██▉       | 137/469 [01:09<02:33,  2.16it/s]
# Epoch 1 in training:  29%|██▉       | 138/469 [01:09<02:33,  2.16it/s]
# Epoch 1 in training:  30%|██▉       | 139/469 [01:10<02:34,  2.14it/s]
# Epoch 1 in training:  30%|██▉       | 140/469 [01:10<02:33,  2.15it/s]
# Epoch 1 in training:  30%|███       | 141/469 [01:11<02:31,  2.16it/s]
# Epoch 1 in training:  30%|███       | 142/469 [01:11<02:32,  2.14it/s]
# Epoch 1 in training:  30%|███       | 143/469 [01:11<02:30,  2.17it/s]
# Epoch 1 in training:  31%|███       | 144/469 [01:12<02:32,  2.14it/s]
# Epoch 1 in training:  31%|███       | 145/469 [01:12<02:30,  2.15it/s]
# Epoch 1 in training:  31%|███       | 146/469 [01:13<02:52,  1.88it/s]
# Epoch 1 in training:  31%|███▏      | 147/469 [01:14<03:03,  1.75it/s]
# Epoch 1 in training:  32%|███▏      | 148/469 [01:14<03:16,  1.64it/s]
# Epoch 1 in training:  32%|███▏      | 149/469 [01:15<03:15,  1.63it/s]
# Epoch 1 in training:  32%|███▏      | 150/469 [01:16<03:02,  1.75it/s]
# Epoch 1 in training:  32%|███▏      | 151/469 [01:16<02:56,  1.81it/s]
# Epoch 1 in training:  32%|███▏      | 152/469 [01:17<02:53,  1.83it/s]
# Epoch 1 in training:  33%|███▎      | 153/469 [01:17<02:52,  1.83it/s]
# Epoch 1 in training:  33%|███▎      | 154/469 [01:18<02:47,  1.88it/s]
# Epoch 1 in training:  33%|███▎      | 155/469 [01:18<02:46,  1.88it/s]
# Epoch 1 in training:  33%|███▎      | 156/469 [01:19<02:43,  1.92it/s]
# Epoch 1 in training:  33%|███▎      | 157/469 [01:19<02:41,  1.93it/s]
# Epoch 1 in training:  34%|███▎      | 158/469 [01:20<02:38,  1.96it/s]
# Epoch 1 in training:  34%|███▍      | 159/469 [01:20<02:38,  1.96it/s]
# Epoch 1 in training:  34%|███▍      | 160/469 [01:21<02:36,  1.97it/s]
# Epoch 1 in training:  34%|███▍      | 161/469 [01:21<02:34,  2.00it/s]
# Epoch 1 in training:  35%|███▍      | 162/469 [01:22<02:29,  2.05it/s]
# Epoch 1 in training:  35%|███▍      | 163/469 [01:22<02:29,  2.04it/s]
# Epoch 1 in training:  35%|███▍      | 164/469 [01:23<02:27,  2.07it/s]
# Epoch 1 in training:  35%|███▌      | 165/469 [01:23<02:26,  2.08it/s]
# Epoch 1 in training:  35%|███▌      | 166/469 [01:24<02:40,  1.89it/s]
# Epoch 1 in training:  36%|███▌      | 167/469 [01:24<02:34,  1.96it/s]
# Epoch 1 in training:  36%|███▌      | 168/469 [01:25<02:28,  2.02it/s]
# Epoch 1 in training:  36%|███▌      | 169/469 [01:25<02:41,  1.86it/s]
# Epoch 1 in training:  36%|███▌      | 170/469 [01:26<02:52,  1.73it/s]
# Epoch 1 in training:  36%|███▋      | 171/469 [01:27<03:04,  1.61it/s]
# Epoch 1 in training:  37%|███▋      | 172/469 [01:27<03:17,  1.51it/s]
# Epoch 1 in training:  37%|███▋      | 173/469 [01:28<02:59,  1.65it/s]
# Epoch 1 in training:  37%|███▋      | 174/469 [01:28<02:46,  1.78it/s]
# Epoch 1 in training:  37%|███▋      | 175/469 [01:29<02:36,  1.88it/s]
# Epoch 1 in training:  38%|███▊      | 176/469 [01:29<02:30,  1.94it/s]
# Epoch 1 in training:  38%|███▊      | 177/469 [01:30<02:25,  2.00it/s]
# Epoch 1 in training:  38%|███▊      | 178/469 [01:30<02:21,  2.05it/s]
# Epoch 1 in training:  38%|███▊      | 179/469 [01:31<02:20,  2.06it/s]
# Epoch 1 in training:  38%|███▊      | 180/469 [01:31<02:19,  2.08it/s]
# Epoch 1 in training:  39%|███▊      | 181/469 [01:32<02:17,  2.10it/s]
# Epoch 1 in training:  39%|███▉      | 182/469 [01:32<02:15,  2.12it/s]
# Epoch 1 in training:  39%|███▉      | 183/469 [01:33<02:14,  2.12it/s]
# Epoch 1 in training:  39%|███▉      | 184/469 [01:33<02:13,  2.13it/s]
# Epoch 1 in training:  39%|███▉      | 185/469 [01:33<02:12,  2.14it/s]
# Epoch 1 in training:  40%|███▉      | 186/469 [01:34<02:11,  2.15it/s]
# Epoch 1 in training:  40%|███▉      | 187/469 [01:34<02:11,  2.14it/s]
# Epoch 1 in training:  40%|████      | 188/469 [01:35<02:10,  2.15it/s]
# Epoch 1 in training:  40%|████      | 189/469 [01:35<02:09,  2.16it/s]
# Epoch 1 in training:  41%|████      | 190/469 [01:36<02:09,  2.16it/s]
# Epoch 1 in training:  41%|████      | 191/469 [01:36<02:09,  2.15it/s]
# Epoch 1 in training:  41%|████      | 192/469 [01:37<02:08,  2.16it/s]
# Epoch 1 in training:  41%|████      | 193/469 [01:37<02:07,  2.16it/s]
# Epoch 1 in training:  41%|████▏     | 194/469 [01:38<02:19,  1.97it/s]
# Epoch 1 in training:  42%|████▏     | 195/469 [01:38<02:30,  1.81it/s]
# Epoch 1 in training:  42%|████▏     | 196/469 [01:39<02:40,  1.70it/s]
# Epoch 1 in training:  42%|████▏     | 197/469 [01:40<02:50,  1.60it/s]
# Epoch 1 in training:  42%|████▏     | 198/469 [01:40<02:35,  1.74it/s]
# Epoch 1 in training:  42%|████▏     | 199/469 [01:41<02:26,  1.85it/s]
# Epoch 1 in training:  43%|████▎     | 200/469 [01:41<02:18,  1.94it/s]
# Epoch 1 in training:  43%|████▎     | 201/469 [01:42<02:13,  2.01it/s]
# Epoch 1 in training:  43%|████▎     | 202/469 [01:42<02:09,  2.06it/s]
# Epoch 1 in training:  43%|████▎     | 203/469 [01:43<02:06,  2.11it/s]
# Epoch 1 in training:  43%|████▎     | 204/469 [01:43<02:06,  2.10it/s]
# Epoch 1 in training:  44%|████▎     | 205/469 [01:44<02:03,  2.13it/s]
# Epoch 1 in training:  44%|████▍     | 206/469 [01:44<02:03,  2.14it/s]
# Epoch 1 in training:  44%|████▍     | 207/469 [01:44<02:01,  2.16it/s]
# Epoch 1 in training:  44%|████▍     | 208/469 [01:45<02:00,  2.16it/s]
# Epoch 1 in training:  45%|████▍     | 209/469 [01:45<01:59,  2.17it/s]
# Epoch 1 in training:  45%|████▍     | 210/469 [01:46<01:59,  2.17it/s]
# Epoch 1 in training:  45%|████▍     | 211/469 [01:46<01:58,  2.17it/s]
# Epoch 1 in training:  45%|████▌     | 212/469 [01:47<01:57,  2.19it/s]
# Epoch 1 in training:  45%|████▌     | 213/469 [01:47<01:58,  2.16it/s]
# Epoch 1 in training:  46%|████▌     | 214/469 [01:48<01:56,  2.19it/s]
# Epoch 1 in training:  46%|████▌     | 215/469 [01:48<01:57,  2.17it/s]
# Epoch 1 in training:  46%|████▌     | 216/469 [01:49<01:56,  2.16it/s]
# Epoch 1 in training:  46%|████▋     | 217/469 [01:49<01:57,  2.15it/s]
# Epoch 1 in training:  46%|████▋     | 218/469 [01:50<01:56,  2.15it/s]
# Epoch 1 in training:  47%|████▋     | 219/469 [01:50<02:05,  1.99it/s]
# Epoch 1 in training:  47%|████▋     | 220/469 [01:51<02:17,  1.82it/s]
# Epoch 1 in training:  47%|████▋     | 221/469 [01:51<02:26,  1.70it/s]
# Epoch 1 in training:  47%|████▋     | 222/469 [01:52<02:36,  1.58it/s]
# Epoch 1 in training:  48%|████▊     | 223/469 [01:53<02:21,  1.73it/s]
# Epoch 1 in training:  48%|████▊     | 224/469 [01:53<02:14,  1.83it/s]
# Epoch 1 in training:  48%|████▊     | 225/469 [01:54<02:06,  1.92it/s]
# Epoch 1 in training:  48%|████▊     | 226/469 [01:54<02:01,  2.00it/s]
# Epoch 1 in training:  48%|████▊     | 227/469 [01:54<01:58,  2.03it/s]
# Epoch 1 in training:  49%|████▊     | 228/469 [01:55<01:56,  2.08it/s]
# Epoch 1 in training:  49%|████▉     | 229/469 [01:55<01:55,  2.07it/s]
# Epoch 1 in training:  49%|████▉     | 230/469 [01:56<01:53,  2.11it/s]
# Epoch 1 in training:  49%|████▉     | 231/469 [01:56<01:53,  2.11it/s]
# Epoch 1 in training:  49%|████▉     | 232/469 [01:57<01:51,  2.13it/s]
# Epoch 1 in training:  50%|████▉     | 233/469 [01:57<01:51,  2.12it/s]
# Epoch 1 in training:  50%|████▉     | 234/469 [01:58<01:49,  2.15it/s]
# Epoch 1 in training:  50%|█████     | 235/469 [01:58<01:48,  2.16it/s]
# Epoch 1 in training:  50%|█████     | 236/469 [01:59<01:46,  2.18it/s]
# Epoch 1 in training:  51%|█████     | 237/469 [01:59<01:46,  2.17it/s]
# Epoch 1 in training:  51%|█████     | 238/469 [02:00<01:46,  2.17it/s]
# Epoch 1 in training:  51%|█████     | 239/469 [02:00<01:45,  2.18it/s]
# Epoch 1 in training:  51%|█████     | 240/469 [02:01<01:45,  2.17it/s]
# Epoch 1 in training:  51%|█████▏    | 241/469 [02:01<01:44,  2.17it/s]
# Epoch 1 in training:  52%|█████▏    | 242/469 [02:01<01:44,  2.17it/s]
# Epoch 1 in training:  52%|█████▏    | 243/469 [02:02<01:43,  2.18it/s]
# Epoch 1 in training:  52%|█████▏    | 244/469 [02:02<01:51,  2.02it/s]
# Epoch 1 in training:  52%|█████▏    | 245/469 [02:03<02:02,  1.84it/s]
# Epoch 1 in training:  52%|█████▏    | 246/469 [02:04<02:09,  1.73it/s]
# Epoch 1 in training:  53%|█████▎    | 247/469 [02:05<02:19,  1.59it/s]
# Epoch 1 in training:  53%|█████▎    | 248/469 [02:05<02:08,  1.72it/s]
# Epoch 1 in training:  53%|█████▎    | 249/469 [02:05<02:00,  1.82it/s]
# Epoch 1 in training:  53%|█████▎    | 250/469 [02:06<01:54,  1.91it/s]
# Epoch 1 in training:  54%|█████▎    | 251/469 [02:06<01:49,  1.98it/s]
# Epoch 1 in training:  54%|█████▎    | 252/469 [02:07<01:47,  2.02it/s]
# Epoch 1 in training:  54%|█████▍    | 253/469 [02:07<01:43,  2.08it/s]
# Epoch 1 in training:  54%|█████▍    | 254/469 [02:08<01:41,  2.11it/s]
# Epoch 1 in training:  54%|█████▍    | 255/469 [02:08<01:41,  2.12it/s]
# Epoch 1 in training:  55%|█████▍    | 256/469 [02:09<01:39,  2.13it/s]
# Epoch 1 in training:  55%|█████▍    | 257/469 [02:09<01:39,  2.13it/s]
# Epoch 1 in training:  55%|█████▌    | 258/469 [02:10<01:38,  2.14it/s]
# Epoch 1 in training:  55%|█████▌    | 259/469 [02:10<01:37,  2.16it/s]
# Epoch 1 in training:  55%|█████▌    | 260/469 [02:11<01:35,  2.18it/s]
# Epoch 1 in training:  56%|█████▌    | 261/469 [02:11<01:35,  2.18it/s]
# Epoch 1 in training:  56%|█████▌    | 262/469 [02:11<01:34,  2.18it/s]
# Epoch 1 in training:  56%|█████▌    | 263/469 [02:12<01:35,  2.17it/s]
# Epoch 1 in training:  56%|█████▋    | 264/469 [02:12<01:34,  2.17it/s]
# Epoch 1 in training:  57%|█████▋    | 265/469 [02:13<01:34,  2.17it/s]
# Epoch 1 in training:  57%|█████▋    | 266/469 [02:13<01:33,  2.18it/s]
# Epoch 1 in training:  57%|█████▋    | 267/469 [02:14<01:34,  2.13it/s]
# Epoch 1 in training:  57%|█████▋    | 268/469 [02:14<01:35,  2.11it/s]
# Epoch 1 in training:  57%|█████▋    | 269/469 [02:15<01:40,  2.00it/s]
# Epoch 1 in training:  58%|█████▊    | 270/469 [02:16<01:49,  1.82it/s]
# Epoch 1 in training:  58%|█████▊    | 271/469 [02:16<01:56,  1.69it/s]
# Epoch 1 in training:  58%|█████▊    | 272/469 [02:17<02:03,  1.59it/s]
# Epoch 1 in training:  58%|█████▊    | 273/469 [02:17<01:55,  1.70it/s]
# Epoch 1 in training:  58%|█████▊    | 274/469 [02:18<01:48,  1.80it/s]
# Epoch 1 in training:  59%|█████▊    | 275/469 [02:18<01:42,  1.90it/s]
# Epoch 1 in training:  59%|█████▉    | 276/469 [02:19<01:37,  1.98it/s]
# Epoch 1 in training:  59%|█████▉    | 277/469 [02:19<01:34,  2.03it/s]
# Epoch 1 in training:  59%|█████▉    | 278/469 [02:20<01:32,  2.07it/s]
# Epoch 1 in training:  59%|█████▉    | 279/469 [02:20<01:31,  2.09it/s]
# Epoch 1 in training:  60%|█████▉    | 280/469 [02:21<01:28,  2.13it/s]
# Epoch 1 in training:  60%|█████▉    | 281/469 [02:21<01:28,  2.12it/s]
# Epoch 1 in training:  60%|██████    | 282/469 [02:22<01:27,  2.15it/s]
# Epoch 1 in training:  60%|██████    | 283/469 [02:22<01:27,  2.13it/s]
# Epoch 1 in training:  61%|██████    | 284/469 [02:22<01:25,  2.16it/s]
# Epoch 1 in training:  61%|██████    | 285/469 [02:23<01:25,  2.16it/s]
# Epoch 1 in training:  61%|██████    | 286/469 [02:23<01:24,  2.16it/s]
# Epoch 1 in training:  61%|██████    | 287/469 [02:24<01:23,  2.18it/s]
# Epoch 1 in training:  61%|██████▏   | 288/469 [02:24<01:23,  2.16it/s]
# Epoch 1 in training:  62%|██████▏   | 289/469 [02:25<01:22,  2.17it/s]
# Epoch 1 in training:  62%|██████▏   | 290/469 [02:25<01:22,  2.16it/s]
# Epoch 1 in training:  62%|██████▏   | 291/469 [02:26<01:22,  2.15it/s]
# Epoch 1 in training:  62%|██████▏   | 292/469 [02:26<01:22,  2.14it/s]
# Epoch 1 in training:  62%|██████▏   | 293/469 [02:27<01:22,  2.12it/s]
# Epoch 1 in training:  63%|██████▎   | 294/469 [02:27<01:38,  1.77it/s]
# Epoch 1 in training:  63%|██████▎   | 295/469 [02:28<01:56,  1.49it/s]
# Epoch 1 in training:  63%|██████▎   | 296/469 [02:29<01:56,  1.49it/s]
# Epoch 1 in training:  63%|██████▎   | 297/469 [02:30<01:58,  1.45it/s]
# Epoch 1 in training:  64%|██████▎   | 298/469 [02:31<02:07,  1.34it/s]
# Epoch 1 in training:  64%|██████▍   | 299/469 [02:31<02:01,  1.40it/s]
# Epoch 1 in training:  64%|██████▍   | 300/469 [02:32<01:48,  1.56it/s]
# Epoch 1 in training:  64%|██████▍   | 301/469 [02:32<01:38,  1.70it/s]
# Epoch 1 in training:  64%|██████▍   | 302/469 [02:33<01:31,  1.82it/s]
# Epoch 1 in training:  65%|██████▍   | 303/469 [02:33<01:26,  1.92it/s]
# Epoch 1 in training:  65%|██████▍   | 304/469 [02:34<01:22,  2.00it/s]
# Epoch 1 in training:  65%|██████▌   | 305/469 [02:34<01:19,  2.05it/s]
# Epoch 1 in training:  65%|██████▌   | 306/469 [02:35<01:18,  2.09it/s]
# Epoch 1 in training:  65%|██████▌   | 307/469 [02:35<01:17,  2.10it/s]
# Epoch 1 in training:  66%|██████▌   | 308/469 [02:35<01:15,  2.13it/s]
# Epoch 1 in training:  66%|██████▌   | 309/469 [02:36<01:14,  2.14it/s]
# Epoch 1 in training:  66%|██████▌   | 310/469 [02:36<01:13,  2.16it/s]
# Epoch 1 in training:  66%|██████▋   | 311/469 [02:37<01:13,  2.15it/s]
# Epoch 1 in training:  67%|██████▋   | 312/469 [02:37<01:13,  2.15it/s]
# Epoch 1 in training:  67%|██████▋   | 313/469 [02:38<01:12,  2.15it/s]
# Epoch 1 in training:  67%|██████▋   | 314/469 [02:38<01:11,  2.16it/s]
# Epoch 1 in training:  67%|██████▋   | 315/469 [02:39<01:11,  2.17it/s]
# Epoch 1 in training:  67%|██████▋   | 316/469 [02:39<01:10,  2.18it/s]
# Epoch 1 in training:  68%|██████▊   | 317/469 [02:40<01:09,  2.19it/s]
# Epoch 1 in training:  68%|██████▊   | 318/469 [02:40<01:09,  2.19it/s]
# Epoch 1 in training:  68%|██████▊   | 319/469 [02:40<01:08,  2.18it/s]
# Epoch 1 in training:  68%|██████▊   | 320/469 [02:41<01:08,  2.17it/s]
# Epoch 1 in training:  68%|██████▊   | 321/469 [02:42<01:15,  1.96it/s]
# Epoch 1 in training:  69%|██████▊   | 322/469 [02:42<01:21,  1.80it/s]
# Epoch 1 in training:  69%|██████▉   | 323/469 [02:43<01:27,  1.68it/s]
# Epoch 1 in training:  69%|██████▉   | 324/469 [02:44<01:29,  1.63it/s]
# Epoch 1 in training:  69%|██████▉   | 325/469 [02:44<01:22,  1.75it/s]
# Epoch 1 in training:  70%|██████▉   | 326/469 [02:45<01:16,  1.86it/s]
# Epoch 1 in training:  70%|██████▉   | 327/469 [02:45<01:13,  1.94it/s]
# Epoch 1 in training:  70%|██████▉   | 328/469 [02:45<01:10,  2.01it/s]
# Epoch 1 in training:  70%|███████   | 329/469 [02:46<01:08,  2.05it/s]
# Epoch 1 in training:  70%|███████   | 330/469 [02:46<01:06,  2.09it/s]
# Epoch 1 in training:  71%|███████   | 331/469 [02:47<01:05,  2.12it/s]
# Epoch 1 in training:  71%|███████   | 332/469 [02:47<01:04,  2.12it/s]
# Epoch 1 in training:  71%|███████   | 333/469 [02:48<01:03,  2.15it/s]
# Epoch 1 in training:  71%|███████   | 334/469 [02:48<01:02,  2.14it/s]
# Epoch 1 in training:  71%|███████▏  | 335/469 [02:49<01:02,  2.15it/s]
# Epoch 1 in training:  72%|███████▏  | 336/469 [02:49<01:01,  2.16it/s]
# Epoch 1 in training:  72%|███████▏  | 337/469 [02:50<01:00,  2.17it/s]
# Epoch 1 in training:  72%|███████▏  | 338/469 [02:50<01:01,  2.14it/s]
# Epoch 1 in training:  72%|███████▏  | 339/469 [02:51<01:00,  2.16it/s]
# Epoch 1 in training:  72%|███████▏  | 340/469 [02:51<00:59,  2.17it/s]
# Epoch 1 in training:  73%|███████▎  | 341/469 [02:51<00:59,  2.16it/s]
# Epoch 1 in training:  73%|███████▎  | 342/469 [02:52<00:58,  2.16it/s]
# Epoch 1 in training:  73%|███████▎  | 343/469 [02:52<00:58,  2.15it/s]
# Epoch 1 in training:  73%|███████▎  | 344/469 [02:53<00:57,  2.18it/s]
# Epoch 1 in training:  74%|███████▎  | 345/469 [02:53<00:57,  2.16it/s]
# Epoch 1 in training:  74%|███████▍  | 346/469 [02:54<01:02,  1.97it/s]
# Epoch 1 in training:  74%|███████▍  | 347/469 [02:55<01:08,  1.79it/s]
# Epoch 1 in training:  74%|███████▍  | 348/469 [02:55<01:13,  1.65it/s]
# Epoch 1 in training:  74%|███████▍  | 349/469 [02:56<01:14,  1.60it/s]
# Epoch 1 in training:  75%|███████▍  | 350/469 [02:56<01:08,  1.73it/s]
# Epoch 1 in training:  75%|███████▍  | 351/469 [02:57<01:03,  1.85it/s]
# Epoch 1 in training:  75%|███████▌  | 352/469 [02:57<01:01,  1.92it/s]
# Epoch 1 in training:  75%|███████▌  | 353/469 [02:58<00:58,  2.00it/s]
# Epoch 1 in training:  75%|███████▌  | 354/469 [02:58<00:56,  2.05it/s]
# Epoch 1 in training:  76%|███████▌  | 355/469 [02:59<00:54,  2.09it/s]
# Epoch 1 in training:  76%|███████▌  | 356/469 [02:59<00:53,  2.11it/s]
# Epoch 1 in training:  76%|███████▌  | 357/469 [03:00<00:52,  2.13it/s]
# Epoch 1 in training:  76%|███████▋  | 358/469 [03:00<00:51,  2.15it/s]
# Epoch 1 in training:  77%|███████▋  | 359/469 [03:01<00:51,  2.14it/s]
# Epoch 1 in training:  77%|███████▋  | 360/469 [03:01<00:50,  2.16it/s]
# Epoch 1 in training:  77%|███████▋  | 361/469 [03:02<00:50,  2.16it/s]
# Epoch 1 in training:  77%|███████▋  | 362/469 [03:02<00:49,  2.17it/s]
# Epoch 1 in training:  77%|███████▋  | 363/469 [03:02<00:48,  2.16it/s]
# Epoch 1 in training:  78%|███████▊  | 364/469 [03:03<00:48,  2.16it/s]
# Epoch 1 in training:  78%|███████▊  | 365/469 [03:03<00:48,  2.16it/s]
# Epoch 1 in training:  78%|███████▊  | 366/469 [03:04<00:47,  2.15it/s]
# Epoch 1 in training:  78%|███████▊  | 367/469 [03:04<00:47,  2.15it/s]
# Epoch 1 in training:  78%|███████▊  | 368/469 [03:05<00:46,  2.16it/s]
# Epoch 1 in training:  79%|███████▊  | 369/469 [03:05<00:46,  2.16it/s]
# Epoch 1 in training:  79%|███████▉  | 370/469 [03:06<00:45,  2.15it/s]
# Epoch 1 in training:  79%|███████▉  | 371/469 [03:06<00:50,  1.94it/s]
# Epoch 1 in training:  79%|███████▉  | 372/469 [03:07<00:54,  1.78it/s]
# Epoch 1 in training:  80%|███████▉  | 373/469 [03:08<00:57,  1.66it/s]
# Epoch 1 in training:  80%|███████▉  | 374/469 [03:08<00:58,  1.62it/s]
# Epoch 1 in training:  80%|███████▉  | 375/469 [03:09<00:53,  1.75it/s]
# Epoch 1 in training:  80%|████████  | 376/469 [03:09<00:50,  1.86it/s]
# Epoch 1 in training:  80%|████████  | 377/469 [03:10<00:47,  1.94it/s]
# Epoch 1 in training:  81%|████████  | 378/469 [03:10<00:45,  2.00it/s]
# Epoch 1 in training:  81%|████████  | 379/469 [03:11<00:43,  2.06it/s]
# Epoch 1 in training:  81%|████████  | 380/469 [03:11<00:42,  2.08it/s]
# Epoch 1 in training:  81%|████████  | 381/469 [03:12<00:41,  2.12it/s]
# Epoch 1 in training:  81%|████████▏ | 382/469 [03:12<00:40,  2.13it/s]
# Epoch 1 in training:  82%|████████▏ | 383/469 [03:12<00:40,  2.14it/s]
# Epoch 1 in training:  82%|████████▏ | 384/469 [03:13<00:39,  2.14it/s]
# Epoch 1 in training:  82%|████████▏ | 385/469 [03:13<00:39,  2.15it/s]
# Epoch 1 in training:  82%|████████▏ | 386/469 [03:14<00:38,  2.15it/s]
# Epoch 1 in training:  83%|████████▎ | 387/469 [03:14<00:37,  2.16it/s]
# Epoch 1 in training:  83%|████████▎ | 388/469 [03:15<00:37,  2.18it/s]
# Epoch 1 in training:  83%|████████▎ | 389/469 [03:15<00:37,  2.15it/s]
# Epoch 1 in training:  83%|████████▎ | 390/469 [03:16<00:36,  2.17it/s]
# Epoch 1 in training:  83%|████████▎ | 391/469 [03:16<00:35,  2.17it/s]
# Epoch 1 in training:  84%|████████▎ | 392/469 [03:17<00:35,  2.17it/s]
# Epoch 1 in training:  84%|████████▍ | 393/469 [03:17<00:35,  2.15it/s]
# Epoch 1 in training:  84%|████████▍ | 394/469 [03:18<00:34,  2.17it/s]
# Epoch 1 in training:  84%|████████▍ | 395/469 [03:18<00:34,  2.15it/s]
# Epoch 1 in training:  84%|████████▍ | 396/469 [03:19<00:37,  1.94it/s]
# Epoch 1 in training:  85%|████████▍ | 397/469 [03:19<00:40,  1.78it/s]
# Epoch 1 in training:  85%|████████▍ | 398/469 [03:20<00:43,  1.65it/s]
# Epoch 1 in training:  85%|████████▌ | 399/469 [03:21<00:43,  1.61it/s]
# Epoch 1 in training:  85%|████████▌ | 400/469 [03:21<00:39,  1.73it/s]
# Epoch 1 in training:  86%|████████▌ | 401/469 [03:22<00:36,  1.85it/s]
# Epoch 1 in training:  86%|████████▌ | 402/469 [03:22<00:34,  1.94it/s]
# Epoch 1 in training:  86%|████████▌ | 403/469 [03:23<00:32,  2.00it/s]
# Epoch 1 in training:  86%|████████▌ | 404/469 [03:23<00:31,  2.06it/s]
# Epoch 1 in training:  86%|████████▋ | 405/469 [03:23<00:30,  2.09it/s]
# Epoch 1 in training:  87%|████████▋ | 406/469 [03:24<00:29,  2.13it/s]
# Epoch 1 in training:  87%|████████▋ | 407/469 [03:24<00:28,  2.14it/s]
# Epoch 1 in training:  87%|████████▋ | 408/469 [03:25<00:28,  2.16it/s]
# Epoch 1 in training:  87%|████████▋ | 409/469 [03:25<00:27,  2.15it/s]
# Epoch 1 in training:  87%|████████▋ | 410/469 [03:26<00:27,  2.13it/s]
# Epoch 1 in training:  88%|████████▊ | 411/469 [03:26<00:27,  2.15it/s]
# Epoch 1 in training:  88%|████████▊ | 412/469 [03:27<00:26,  2.14it/s]
# Epoch 1 in training:  88%|████████▊ | 413/469 [03:27<00:26,  2.12it/s]
# Epoch 1 in training:  88%|████████▊ | 414/469 [03:28<00:25,  2.13it/s]
# Epoch 1 in training:  88%|████████▊ | 415/469 [03:28<00:25,  2.16it/s]
# Epoch 1 in training:  89%|████████▊ | 416/469 [03:29<00:24,  2.15it/s]
# Epoch 1 in training:  89%|████████▉ | 417/469 [03:29<00:24,  2.17it/s]
# Epoch 1 in training:  89%|████████▉ | 418/469 [03:29<00:23,  2.16it/s]
# Epoch 1 in training:  89%|████████▉ | 419/469 [03:30<00:23,  2.17it/s]
# Epoch 1 in training:  90%|████████▉ | 420/469 [03:30<00:22,  2.15it/s]
# Epoch 1 in training:  90%|████████▉ | 421/469 [03:31<00:24,  1.94it/s]
# Epoch 1 in training:  90%|████████▉ | 422/469 [03:32<00:26,  1.78it/s]
# Epoch 1 in training:  90%|█████████ | 423/469 [03:32<00:27,  1.68it/s]
# Epoch 1 in training:  90%|█████████ | 424/469 [03:33<00:30,  1.49it/s]
# Epoch 1 in training:  91%|█████████ | 425/469 [03:34<00:26,  1.65it/s]
# Epoch 1 in training:  91%|█████████ | 426/469 [03:34<00:24,  1.78it/s]
# Epoch 1 in training:  91%|█████████ | 427/469 [03:35<00:22,  1.87it/s]
# Epoch 1 in training:  91%|█████████▏| 428/469 [03:35<00:20,  1.95it/s]
# Epoch 1 in training:  91%|█████████▏| 429/469 [03:36<00:19,  2.02it/s]
# Epoch 1 in training:  92%|█████████▏| 430/469 [03:36<00:19,  2.04it/s]
# Epoch 1 in training:  92%|█████████▏| 431/469 [03:36<00:18,  2.08it/s]
# Epoch 1 in training:  92%|█████████▏| 432/469 [03:37<00:17,  2.07it/s]
# Epoch 1 in training:  92%|█████████▏| 433/469 [03:37<00:17,  2.11it/s]
# Epoch 1 in training:  93%|█████████▎| 434/469 [03:38<00:16,  2.11it/s]
# Epoch 1 in training:  93%|█████████▎| 435/469 [03:38<00:15,  2.13it/s]
# Epoch 1 in training:  93%|█████████▎| 436/469 [03:39<00:15,  2.14it/s]
# Epoch 1 in training:  93%|█████████▎| 437/469 [03:39<00:14,  2.15it/s]
# Epoch 1 in training:  93%|█████████▎| 438/469 [03:40<00:14,  2.14it/s]
# Epoch 1 in training:  94%|█████████▎| 439/469 [03:40<00:13,  2.15it/s]
# Epoch 1 in training:  94%|█████████▍| 440/469 [03:41<00:13,  2.16it/s]
# Epoch 1 in training:  94%|█████████▍| 441/469 [03:41<00:12,  2.16it/s]
# Epoch 1 in training:  94%|█████████▍| 442/469 [03:42<00:12,  2.18it/s]
# Epoch 1 in training:  94%|█████████▍| 443/469 [03:42<00:11,  2.17it/s]
# Epoch 1 in training:  95%|█████████▍| 444/469 [03:43<00:11,  2.18it/s]
# Epoch 1 in training:  95%|█████████▍| 445/469 [03:43<00:11,  2.15it/s]
# Epoch 1 in training:  95%|█████████▌| 446/469 [03:44<00:12,  1.90it/s]
# Epoch 1 in training:  95%|█████████▌| 447/469 [03:44<00:12,  1.75it/s]
# Epoch 1 in training:  96%|█████████▌| 448/469 [03:45<00:12,  1.63it/s]
# Epoch 1 in training:  96%|█████████▌| 449/469 [03:46<00:11,  1.67it/s]
# Epoch 1 in training:  96%|█████████▌| 450/469 [03:46<00:10,  1.79it/s]
# Epoch 1 in training:  96%|█████████▌| 451/469 [03:47<00:09,  1.88it/s]
# Epoch 1 in training:  96%|█████████▋| 452/469 [03:47<00:08,  1.94it/s]
# Epoch 1 in training:  97%|█████████▋| 453/469 [03:47<00:07,  2.01it/s]
# Epoch 1 in training:  97%|█████████▋| 454/469 [03:48<00:07,  2.06it/s]
# Epoch 1 in training:  97%|█████████▋| 455/469 [03:48<00:06,  2.08it/s]
# Epoch 1 in training:  97%|█████████▋| 456/469 [03:49<00:06,  2.11it/s]
# Epoch 1 in training:  97%|█████████▋| 457/469 [03:49<00:05,  2.13it/s]
# Epoch 1 in training:  98%|█████████▊| 458/469 [03:50<00:05,  2.14it/s]
# Epoch 1 in training:  98%|█████████▊| 459/469 [03:50<00:04,  2.13it/s]
# Epoch 1 in training:  98%|█████████▊| 460/469 [03:51<00:04,  2.15it/s]
# Epoch 1 in training:  98%|█████████▊| 461/469 [03:51<00:03,  2.15it/s]
# Epoch 1 in training:  99%|█████████▊| 462/469 [03:52<00:03,  2.17it/s]
# Epoch 1 in training:  99%|█████████▊| 463/469 [03:52<00:02,  2.17it/s]
# Epoch 1 in training:  99%|█████████▉| 464/469 [03:53<00:02,  2.16it/s]
# Epoch 1 in training:  99%|█████████▉| 465/469 [03:53<00:01,  2.18it/s]
# Epoch 1 in training:  99%|█████████▉| 466/469 [03:53<00:01,  2.18it/s]
# Epoch 1 in training: 100%|█████████▉| 467/469 [03:54<00:00,  2.18it/s]
# Epoch 1 in training: 100%|█████████▉| 468/469 [03:54<00:00,  2.15it/s]
# Epoch 1 in training: 100%|██████████| 469/469 [03:55<00:00,  2.31it/s]
# Training:  20%|██        | 1/5 [03:55<15:41, 235.28s/it]
# Epoch 1/5 loss: 2.00
# Epoch 2 in training:   0%|          | 0/469 [00:00<?, ?it/s]
# Epoch 2 in training:   0%|          | 1/469 [00:00<03:47,  2.06it/s]
# Epoch 2 in training:   0%|          | 2/469 [00:01<04:37,  1.68it/s]
# Epoch 2 in training:   1%|          | 3/469 [00:01<04:51,  1.60it/s]
# Epoch 2 in training:   1%|          | 4/469 [00:02<05:09,  1.50it/s]
# Epoch 2 in training:   1%|          | 5/469 [00:03<04:59,  1.55it/s]
# Epoch 2 in training:   1%|▏         | 6/469 [00:03<04:32,  1.70it/s]
# Epoch 2 in training:   1%|▏         | 7/469 [00:04<04:11,  1.84it/s]
# Epoch 2 in training:   2%|▏         | 8/469 [00:04<03:57,  1.94it/s]
# Epoch 2 in training:   2%|▏         | 9/469 [00:04<03:48,  2.01it/s]
# Epoch 2 in training:   2%|▏         | 10/469 [00:05<03:41,  2.08it/s]
# Epoch 2 in training:   2%|▏         | 11/469 [00:05<03:38,  2.10it/s]
# Epoch 2 in training:   3%|▎         | 12/469 [00:06<03:35,  2.12it/s]
# Epoch 2 in training:   3%|▎         | 13/469 [00:06<03:34,  2.12it/s]
# Epoch 2 in training:   3%|▎         | 14/469 [00:07<03:33,  2.14it/s]
# Epoch 2 in training:   3%|▎         | 15/469 [00:07<03:32,  2.14it/s]
# Epoch 2 in training:   3%|▎         | 16/469 [00:08<03:31,  2.14it/s]
# Epoch 2 in training:   4%|▎         | 17/469 [00:08<03:31,  2.14it/s]
# Epoch 2 in training:   4%|▍         | 18/469 [00:09<03:30,  2.14it/s]
# Epoch 2 in training:   4%|▍         | 19/469 [00:09<03:29,  2.15it/s]
# Epoch 2 in training:   4%|▍         | 20/469 [00:10<03:28,  2.15it/s]
# Epoch 2 in training:   4%|▍         | 21/469 [00:10<03:27,  2.16it/s]
# Epoch 2 in training:   5%|▍         | 22/469 [00:11<03:28,  2.14it/s]
# Epoch 2 in training:   5%|▍         | 23/469 [00:11<03:26,  2.16it/s]
# Epoch 2 in training:   5%|▌         | 24/469 [00:11<03:27,  2.14it/s]
# Epoch 2 in training:   5%|▌         | 25/469 [00:12<03:27,  2.14it/s]
# Epoch 2 in training:   6%|▌         | 26/469 [00:12<03:27,  2.13it/s]
# Epoch 2 in training:   6%|▌         | 27/469 [00:13<03:54,  1.88it/s]
# Epoch 2 in training:   6%|▌         | 28/469 [00:14<04:12,  1.75it/s]
# Epoch 2 in training:   6%|▌         | 29/469 [00:14<04:31,  1.62it/s]
# Epoch 2 in training:   6%|▋         | 30/469 [00:15<04:27,  1.64it/s]
# Epoch 2 in training:   7%|▋         | 31/469 [00:16<04:08,  1.76it/s]
# Epoch 2 in training:   7%|▋         | 32/469 [00:16<03:53,  1.87it/s]
# Epoch 2 in training:   7%|▋         | 33/469 [00:16<03:44,  1.94it/s]
# Epoch 2 in training:   7%|▋         | 34/469 [00:17<03:36,  2.01it/s]
# Epoch 2 in training:   7%|▋         | 35/469 [00:17<03:30,  2.06it/s]
# Epoch 2 in training:   8%|▊         | 36/469 [00:18<03:27,  2.09it/s]
# Epoch 2 in training:   8%|▊         | 37/469 [00:18<03:24,  2.11it/s]
# Epoch 2 in training:   8%|▊         | 38/469 [00:19<03:23,  2.12it/s]
# Epoch 2 in training:   8%|▊         | 39/469 [00:19<03:20,  2.14it/s]
# Epoch 2 in training:   9%|▊         | 40/469 [00:20<03:20,  2.14it/s]
# Epoch 2 in training:   9%|▊         | 41/469 [00:20<03:18,  2.16it/s]
# Epoch 2 in training:   9%|▉         | 42/469 [00:21<03:19,  2.14it/s]
# Epoch 2 in training:   9%|▉         | 43/469 [00:21<03:16,  2.16it/s]
# Epoch 2 in training:   9%|▉         | 44/469 [00:22<03:15,  2.17it/s]
# Epoch 2 in training:  10%|▉         | 45/469 [00:22<03:18,  2.14it/s]
# Epoch 2 in training:  10%|▉         | 46/469 [00:22<03:16,  2.15it/s]
# Epoch 2 in training:  10%|█         | 47/469 [00:23<03:17,  2.14it/s]
# Epoch 2 in training:  10%|█         | 48/469 [00:23<03:15,  2.16it/s]
# Epoch 2 in training:  10%|█         | 49/469 [00:24<03:16,  2.14it/s]
# Epoch 2 in training:  11%|█         | 50/469 [00:24<03:15,  2.15it/s]
# Epoch 2 in training:  11%|█         | 51/469 [00:25<03:16,  2.13it/s]
# Epoch 2 in training:  11%|█         | 52/469 [00:25<03:42,  1.87it/s]
# Epoch 2 in training:  11%|█▏        | 53/469 [00:26<03:57,  1.75it/s]
# Epoch 2 in training:  12%|█▏        | 54/469 [00:27<04:15,  1.62it/s]
# Epoch 2 in training:  12%|█▏        | 55/469 [00:27<04:08,  1.67it/s]
# Epoch 2 in training:  12%|█▏        | 56/469 [00:28<03:52,  1.78it/s]
# Epoch 2 in training:  12%|█▏        | 57/469 [00:28<03:38,  1.89it/s]
# Epoch 2 in training:  12%|█▏        | 58/469 [00:29<03:31,  1.94it/s]
# Epoch 2 in training:  13%|█▎        | 59/469 [00:29<03:24,  2.01it/s]
# Epoch 2 in training:  13%|█▎        | 60/469 [00:30<03:20,  2.04it/s]
# Epoch 2 in training:  13%|█▎        | 61/469 [00:30<03:17,  2.07it/s]
# Epoch 2 in training:  13%|█▎        | 62/469 [00:31<03:16,  2.07it/s]
# Epoch 2 in training:  13%|█▎        | 63/469 [00:31<03:14,  2.09it/s]
# Epoch 2 in training:  14%|█▎        | 64/469 [00:32<03:35,  1.88it/s]
# Epoch 2 in training:  14%|█▍        | 65/469 [00:32<03:29,  1.93it/s]
# Epoch 2 in training:  14%|█▍        | 66/469 [00:33<03:22,  1.99it/s]
# Epoch 2 in training:  14%|█▍        | 67/469 [00:33<03:19,  2.01it/s]
# Epoch 2 in training:  14%|█▍        | 68/469 [00:34<03:14,  2.06it/s]
# Epoch 2 in training:  15%|█▍        | 69/469 [00:34<03:11,  2.09it/s]
# Epoch 2 in training:  15%|█▍        | 70/469 [00:35<03:09,  2.11it/s]
# Epoch 2 in training:  15%|█▌        | 71/469 [00:35<03:07,  2.12it/s]
# Epoch 2 in training:  15%|█▌        | 72/469 [00:36<03:05,  2.14it/s]
# Epoch 2 in training:  16%|█▌        | 73/469 [00:36<03:06,  2.13it/s]
# Epoch 2 in training:  16%|█▌        | 74/469 [00:37<03:04,  2.14it/s]
# Epoch 2 in training:  16%|█▌        | 75/469 [00:37<03:02,  2.15it/s]
# Epoch 2 in training:  16%|█▌        | 76/469 [00:38<03:21,  1.95it/s]
# Epoch 2 in training:  16%|█▋        | 77/469 [00:38<03:39,  1.79it/s]
# Epoch 2 in training:  17%|█▋        | 78/469 [00:39<03:53,  1.68it/s]
# Epoch 2 in training:  17%|█▋        | 79/469 [00:40<04:05,  1.59it/s]
# Epoch 2 in training:  17%|█▋        | 80/469 [00:40<03:50,  1.69it/s]
# Epoch 2 in training:  17%|█▋        | 81/469 [00:41<03:38,  1.78it/s]
# Epoch 2 in training:  17%|█▋        | 82/469 [00:41<03:26,  1.87it/s]
# Epoch 2 in training:  18%|█▊        | 83/469 [00:42<03:19,  1.94it/s]
# Epoch 2 in training:  18%|█▊        | 84/469 [00:42<03:11,  2.01it/s]
# Epoch 2 in training:  18%|█▊        | 85/469 [00:43<03:07,  2.05it/s]
# Epoch 2 in training:  18%|█▊        | 86/469 [00:43<03:04,  2.07it/s]
# Epoch 2 in training:  19%|█▊        | 87/469 [00:43<03:02,  2.09it/s]
# Epoch 2 in training:  19%|█▉        | 88/469 [00:44<02:59,  2.12it/s]
# Epoch 2 in training:  19%|█▉        | 89/469 [00:44<02:58,  2.13it/s]
# Epoch 2 in training:  19%|█▉        | 90/469 [00:45<02:58,  2.12it/s]
# Epoch 2 in training:  19%|█▉        | 91/469 [00:45<02:58,  2.12it/s]
# Epoch 2 in training:  20%|█▉        | 92/469 [00:46<02:57,  2.13it/s]
# Epoch 2 in training:  20%|█▉        | 93/469 [00:46<02:54,  2.16it/s]
# Epoch 2 in training:  20%|██        | 94/469 [00:47<02:54,  2.14it/s]
# Epoch 2 in training:  20%|██        | 95/469 [00:47<02:53,  2.16it/s]
# Epoch 2 in training:  20%|██        | 96/469 [00:48<02:54,  2.14it/s]
# Epoch 2 in training:  21%|██        | 97/469 [00:48<02:53,  2.15it/s]
# Epoch 2 in training:  21%|██        | 98/469 [00:49<02:52,  2.15it/s]
# Epoch 2 in training:  21%|██        | 99/469 [00:49<02:51,  2.16it/s]
# Epoch 2 in training:  21%|██▏       | 100/469 [00:50<02:51,  2.16it/s]
# Epoch 2 in training:  22%|██▏       | 101/469 [00:50<03:10,  1.93it/s]
# Epoch 2 in training:  22%|██▏       | 102/469 [00:51<03:29,  1.75it/s]
# Epoch 2 in training:  22%|██▏       | 103/469 [00:52<03:45,  1.63it/s]
# Epoch 2 in training:  22%|██▏       | 104/469 [00:52<03:44,  1.62it/s]
# Epoch 2 in training:  22%|██▏       | 105/469 [00:53<03:32,  1.72it/s]
# Epoch 2 in training:  23%|██▎       | 106/469 [00:53<03:21,  1.80it/s]
# Epoch 2 in training:  23%|██▎       | 107/469 [00:54<03:12,  1.88it/s]
# Epoch 2 in training:  23%|██▎       | 108/469 [00:54<03:04,  1.96it/s]
# Epoch 2 in training:  23%|██▎       | 109/469 [00:55<02:57,  2.03it/s]
# Epoch 2 in training:  23%|██▎       | 110/469 [00:55<02:54,  2.05it/s]
# Epoch 2 in training:  24%|██▎       | 111/469 [00:55<02:49,  2.11it/s]
# Epoch 2 in training:  24%|██▍       | 112/469 [00:56<02:48,  2.11it/s]
# Epoch 2 in training:  24%|██▍       | 113/469 [00:56<02:54,  2.04it/s]
# Epoch 2 in training:  24%|██▍       | 114/469 [00:57<03:01,  1.95it/s]
# Epoch 2 in training:  25%|██▍       | 115/469 [00:58<03:08,  1.88it/s]
# Epoch 2 in training:  25%|██▍       | 116/469 [00:58<03:06,  1.89it/s]
# Epoch 2 in training:  25%|██▍       | 117/469 [00:59<03:00,  1.95it/s]
# Epoch 2 in training:  25%|██▌       | 118/469 [00:59<02:55,  2.00it/s]
# Epoch 2 in training:  25%|██▌       | 119/469 [01:00<02:50,  2.06it/s]
# Epoch 2 in training:  26%|██▌       | 120/469 [01:00<02:49,  2.06it/s]
# Epoch 2 in training:  26%|██▌       | 121/469 [01:01<02:47,  2.07it/s]
# Epoch 2 in training:  26%|██▌       | 122/469 [01:01<02:47,  2.07it/s]
# Epoch 2 in training:  26%|██▌       | 123/469 [01:01<02:45,  2.10it/s]
# Epoch 2 in training:  26%|██▋       | 124/469 [01:02<02:44,  2.09it/s]
# Epoch 2 in training:  27%|██▋       | 125/469 [01:03<03:04,  1.86it/s]
# Epoch 2 in training:  27%|██▋       | 126/469 [01:03<03:17,  1.73it/s]
# Epoch 2 in training:  27%|██▋       | 127/469 [01:04<03:30,  1.62it/s]
# Epoch 2 in training:  27%|██▋       | 128/469 [01:05<03:28,  1.63it/s]
# Epoch 2 in training:  28%|██▊       | 129/469 [01:05<03:13,  1.76it/s]
# Epoch 2 in training:  28%|██▊       | 130/469 [01:06<03:01,  1.87it/s]
# Epoch 2 in training:  28%|██▊       | 131/469 [01:06<02:52,  1.95it/s]
# Epoch 2 in training:  28%|██▊       | 132/469 [01:06<02:47,  2.01it/s]
# Epoch 2 in training:  28%|██▊       | 133/469 [01:07<02:45,  2.03it/s]
# Epoch 2 in training:  29%|██▊       | 134/469 [01:07<02:41,  2.07it/s]
# Epoch 2 in training:  29%|██▉       | 135/469 [01:08<02:39,  2.10it/s]
# Epoch 2 in training:  29%|██▉       | 136/469 [01:08<02:37,  2.12it/s]
# Epoch 2 in training:  29%|██▉       | 137/469 [01:09<02:34,  2.15it/s]
# Epoch 2 in training:  29%|██▉       | 138/469 [01:09<02:34,  2.14it/s]
# Epoch 2 in training:  30%|██▉       | 139/469 [01:10<02:33,  2.16it/s]
# Epoch 2 in training:  30%|██▉       | 140/469 [01:10<02:33,  2.15it/s]
# Epoch 2 in training:  30%|███       | 141/469 [01:11<02:31,  2.16it/s]
# Epoch 2 in training:  30%|███       | 142/469 [01:11<02:31,  2.16it/s]
# Epoch 2 in training:  30%|███       | 143/469 [01:12<02:31,  2.15it/s]
# Epoch 2 in training:  31%|███       | 144/469 [01:12<02:30,  2.16it/s]
# Epoch 2 in training:  31%|███       | 145/469 [01:12<02:29,  2.17it/s]
# Epoch 2 in training:  31%|███       | 146/469 [01:13<02:28,  2.17it/s]
# Epoch 2 in training:  31%|███▏      | 147/469 [01:13<02:29,  2.15it/s]
# Epoch 2 in training:  32%|███▏      | 148/469 [01:14<02:28,  2.16it/s]
# Epoch 2 in training:  32%|███▏      | 149/469 [01:14<02:29,  2.14it/s]
# Epoch 2 in training:  32%|███▏      | 150/469 [01:15<02:49,  1.89it/s]
# Epoch 2 in training:  32%|███▏      | 151/469 [01:16<03:00,  1.76it/s]
# Epoch 2 in training:  32%|███▏      | 152/469 [01:16<03:12,  1.64it/s]
# Epoch 2 in training:  33%|███▎      | 153/469 [01:17<03:12,  1.64it/s]
# Epoch 2 in training:  33%|███▎      | 154/469 [01:17<02:58,  1.76it/s]
# Epoch 2 in training:  33%|███▎      | 155/469 [01:18<02:47,  1.88it/s]
# Epoch 2 in training:  33%|███▎      | 156/469 [01:18<02:40,  1.95it/s]
# Epoch 2 in training:  33%|███▎      | 157/469 [01:19<02:35,  2.00it/s]
# Epoch 2 in training:  34%|███▎      | 158/469 [01:19<02:30,  2.06it/s]
# Epoch 2 in training:  34%|███▍      | 159/469 [01:20<02:29,  2.07it/s]
# Epoch 2 in training:  34%|███▍      | 160/469 [01:20<02:27,  2.10it/s]
# Epoch 2 in training:  34%|███▍      | 161/469 [01:21<02:25,  2.11it/s]
# Epoch 2 in training:  35%|███▍      | 162/469 [01:21<02:24,  2.13it/s]
# Epoch 2 in training:  35%|███▍      | 163/469 [01:22<02:24,  2.12it/s]
# Epoch 2 in training:  35%|███▍      | 164/469 [01:22<02:22,  2.14it/s]
# Epoch 2 in training:  35%|███▌      | 165/469 [01:23<02:22,  2.13it/s]
# Epoch 2 in training:  35%|███▌      | 166/469 [01:23<02:21,  2.14it/s]
# Epoch 2 in training:  36%|███▌      | 167/469 [01:23<02:19,  2.16it/s]
# Epoch 2 in training:  36%|███▌      | 168/469 [01:24<02:20,  2.15it/s]
# Epoch 2 in training:  36%|███▌      | 169/469 [01:24<02:18,  2.16it/s]
# Epoch 2 in training:  36%|███▌      | 170/469 [01:25<02:19,  2.14it/s]
# Epoch 2 in training:  36%|███▋      | 171/469 [01:25<02:19,  2.13it/s]
# Epoch 2 in training:  37%|███▋      | 172/469 [01:26<02:19,  2.13it/s]
# Epoch 2 in training:  37%|███▋      | 173/469 [01:26<02:18,  2.14it/s]
# Epoch 2 in training:  37%|███▋      | 174/469 [01:27<02:18,  2.14it/s]
# Epoch 2 in training:  37%|███▋      | 175/469 [01:27<02:36,  1.87it/s]
# Epoch 2 in training:  38%|███▊      | 176/469 [01:28<02:48,  1.74it/s]
# Epoch 2 in training:  38%|███▊      | 177/469 [01:29<02:59,  1.63it/s]
# Epoch 2 in training:  38%|███▊      | 178/469 [01:29<02:56,  1.65it/s]
# Epoch 2 in training:  38%|███▊      | 179/469 [01:30<02:43,  1.77it/s]
# Epoch 2 in training:  38%|███▊      | 180/469 [01:30<02:34,  1.87it/s]
# Epoch 2 in training:  39%|███▊      | 181/469 [01:31<02:29,  1.93it/s]
# Epoch 2 in training:  39%|███▉      | 182/469 [01:31<02:22,  2.01it/s]
# Epoch 2 in training:  39%|███▉      | 183/469 [01:32<02:20,  2.04it/s]
# Epoch 2 in training:  39%|███▉      | 184/469 [01:32<02:18,  2.05it/s]
# Epoch 2 in training:  39%|███▉      | 185/469 [01:33<02:16,  2.08it/s]
# Epoch 2 in training:  40%|███▉      | 186/469 [01:33<02:15,  2.09it/s]
# Epoch 2 in training:  40%|███▉      | 187/469 [01:34<02:13,  2.11it/s]
# Epoch 2 in training:  40%|████      | 188/469 [01:34<02:13,  2.10it/s]
# Epoch 2 in training:  40%|████      | 189/469 [01:35<02:25,  1.92it/s]
# Epoch 2 in training:  41%|████      | 190/469 [01:35<02:28,  1.88it/s]
# Epoch 2 in training:  41%|████      | 191/469 [01:36<02:41,  1.72it/s]
# Epoch 2 in training:  41%|████      | 192/469 [01:37<02:49,  1.64it/s]
# Epoch 2 in training:  41%|████      | 193/469 [01:37<02:59,  1.54it/s]
# Epoch 2 in training:  41%|████▏     | 194/469 [01:38<02:48,  1.63it/s]
# Epoch 2 in training:  42%|████▏     | 195/469 [01:38<02:36,  1.75it/s]
# Epoch 2 in training:  42%|████▏     | 196/469 [01:39<02:26,  1.86it/s]
# Epoch 2 in training:  42%|████▏     | 197/469 [01:39<02:30,  1.81it/s]
# Epoch 2 in training:  42%|████▏     | 198/469 [01:40<02:39,  1.70it/s]
# Epoch 2 in training:  42%|████▏     | 199/469 [01:41<02:46,  1.62it/s]
# Epoch 2 in training:  43%|████▎     | 200/469 [01:42<02:56,  1.52it/s]
# Epoch 2 in training:  43%|████▎     | 201/469 [01:42<02:41,  1.66it/s]
# ...
# Epoch 5 in training:  53%|█████▎    | 248/469 [02:04<02:01,  1.81it/s]
# Epoch 5 in training:  53%|█████▎    | 249/469 [02:05<02:08,  1.71it/s]
# Epoch 5 in training:  53%|█████▎    | 250/469 [02:05<02:18,  1.59it/s]
# Epoch 5 in training:  54%|█████▎    | 251/469 [02:06<02:08,  1.70it/s]
# Epoch 5 in training:  54%|█████▎    | 252/469 [02:06<01:59,  1.81it/s]
# Epoch 5 in training:  54%|█████▍    | 253/469 [02:07<01:52,  1.91it/s]
# Epoch 5 in training:  54%|█████▍    | 254/469 [02:07<01:49,  1.96it/s]
# Epoch 5 in training:  54%|█████▍    | 255/469 [02:08<01:46,  2.01it/s]
# Epoch 5 in training:  55%|█████▍    | 256/469 [02:08<01:44,  2.04it/s]
# Epoch 5 in training:  55%|█████▍    | 257/469 [02:09<01:41,  2.08it/s]
# Epoch 5 in training:  55%|█████▌    | 258/469 [02:09<01:40,  2.10it/s]
# Epoch 5 in training:  55%|█████▌    | 259/469 [02:10<01:39,  2.12it/s]
# Epoch 5 in training:  55%|█████▌    | 260/469 [02:10<01:37,  2.14it/s]
# Epoch 5 in training:  56%|█████▌    | 261/469 [02:10<01:37,  2.14it/s]
# Epoch 5 in training:  56%|█████▌    | 262/469 [02:11<01:36,  2.15it/s]
# Epoch 5 in training:  56%|█████▌    | 263/469 [02:11<01:36,  2.15it/s]
# Epoch 5 in training:  56%|█████▋    | 264/469 [02:12<01:35,  2.16it/s]
# Epoch 5 in training:  57%|█████▋    | 265/469 [02:12<01:35,  2.13it/s]
# Epoch 5 in training:  57%|█████▋    | 266/469 [02:13<01:34,  2.14it/s]
# Epoch 5 in training:  57%|█████▋    | 267/469 [02:13<01:35,  2.11it/s]
# Epoch 5 in training:  57%|█████▋    | 268/469 [02:14<01:35,  2.11it/s]
# Epoch 5 in training:  57%|█████▋    | 269/469 [02:14<01:34,  2.11it/s]
# Epoch 5 in training:  58%|█████▊    | 270/469 [02:15<01:32,  2.14it/s]
# Epoch 5 in training:  58%|█████▊    | 271/469 [02:15<01:31,  2.15it/s]
# Epoch 5 in training:  58%|█████▊    | 272/469 [02:16<01:38,  2.00it/s]
# Epoch 5 in training:  58%|█████▊    | 273/469 [02:16<01:47,  1.82it/s]
# Epoch 5 in training:  58%|█████▊    | 274/469 [02:17<01:55,  1.69it/s]
# Epoch 5 in training:  59%|█████▊    | 275/469 [02:18<02:04,  1.56it/s]
# Epoch 5 in training:  59%|█████▉    | 276/469 [02:18<01:54,  1.68it/s]
# Epoch 5 in training:  59%|█████▉    | 277/469 [02:19<01:45,  1.82it/s]
# Epoch 5 in training:  59%|█████▉    | 278/469 [02:19<01:39,  1.92it/s]
# Epoch 5 in training:  59%|█████▉    | 279/469 [02:20<01:36,  1.98it/s]
# Epoch 5 in training:  60%|█████▉    | 280/469 [02:20<01:32,  2.03it/s]
# Epoch 5 in training:  60%|█████▉    | 281/469 [02:21<01:31,  2.06it/s]
# Epoch 5 in training:  60%|██████    | 282/469 [02:21<01:29,  2.08it/s]
# Epoch 5 in training:  60%|██████    | 283/469 [02:22<01:28,  2.10it/s]
# Epoch 5 in training:  61%|██████    | 284/469 [02:22<01:27,  2.12it/s]
# Epoch 5 in training:  61%|██████    | 285/469 [02:23<01:26,  2.12it/s]
# Epoch 5 in training:  61%|██████    | 286/469 [02:23<01:25,  2.15it/s]
# Epoch 5 in training:  61%|██████    | 287/469 [02:23<01:24,  2.16it/s]
# Epoch 5 in training:  61%|██████▏   | 288/469 [02:24<01:24,  2.15it/s]
# Epoch 5 in training:  62%|██████▏   | 289/469 [02:24<01:23,  2.15it/s]
# Epoch 5 in training:  62%|██████▏   | 290/469 [02:25<01:23,  2.15it/s]
# Epoch 5 in training:  62%|██████▏   | 291/469 [02:25<01:22,  2.15it/s]
# Epoch 5 in training:  62%|██████▏   | 292/469 [02:26<01:22,  2.14it/s]
# Epoch 5 in training:  62%|██████▏   | 293/469 [02:26<01:22,  2.15it/s]
# Epoch 5 in training:  63%|██████▎   | 294/469 [02:27<01:22,  2.13it/s]
# Epoch 5 in training:  63%|██████▎   | 295/469 [02:27<01:21,  2.14it/s]
# Epoch 5 in training:  63%|██████▎   | 296/469 [02:28<01:21,  2.12it/s]
# Epoch 5 in training:  63%|██████▎   | 297/469 [02:28<01:28,  1.95it/s]
# Epoch 5 in training:  64%|██████▎   | 298/469 [02:29<01:35,  1.78it/s]
# Epoch 5 in training:  64%|██████▍   | 299/469 [02:30<01:42,  1.66it/s]
# Epoch 5 in training:  64%|██████▍   | 300/469 [02:30<01:53,  1.49it/s]
# Epoch 5 in training:  64%|██████▍   | 301/469 [02:31<01:56,  1.44it/s]
# Epoch 5 in training:  64%|██████▍   | 302/469 [02:32<01:55,  1.44it/s]
# Epoch 5 in training:  65%|██████▍   | 303/469 [02:33<01:56,  1.43it/s]
# Epoch 5 in training:  65%|██████▍   | 304/469 [02:33<01:44,  1.58it/s]
# Epoch 5 in training:  65%|██████▌   | 305/469 [02:34<01:35,  1.72it/s]
# Epoch 5 in training:  65%|██████▌   | 306/469 [02:34<01:29,  1.83it/s]
# Epoch 5 in training:  65%|██████▌   | 307/469 [02:34<01:25,  1.90it/s]
# Epoch 5 in training:  66%|██████▌   | 308/469 [02:35<01:21,  1.97it/s]
# Epoch 5 in training:  66%|██████▌   | 309/469 [02:35<01:18,  2.03it/s]
# Epoch 5 in training:  66%|██████▌   | 310/469 [02:36<01:16,  2.07it/s]
# Epoch 5 in training:  66%|██████▋   | 311/469 [02:36<01:15,  2.09it/s]
# Epoch 5 in training:  67%|██████▋   | 312/469 [02:37<01:14,  2.11it/s]
# Epoch 5 in training:  67%|██████▋   | 313/469 [02:37<01:14,  2.10it/s]
# Epoch 5 in training:  67%|██████▋   | 314/469 [02:38<01:12,  2.13it/s]
# Epoch 5 in training:  67%|██████▋   | 315/469 [02:38<01:12,  2.12it/s]
# Epoch 5 in training:  67%|██████▋   | 316/469 [02:39<01:11,  2.13it/s]
# Epoch 5 in training:  68%|██████▊   | 317/469 [02:39<01:11,  2.13it/s]
# Epoch 5 in training:  68%|██████▊   | 318/469 [02:40<01:10,  2.14it/s]
# Epoch 5 in training:  68%|██████▊   | 319/469 [02:40<01:10,  2.14it/s]
# Epoch 5 in training:  68%|██████▊   | 320/469 [02:41<01:09,  2.14it/s]
# Epoch 5 in training:  68%|██████▊   | 321/469 [02:41<01:10,  2.10it/s]
# Epoch 5 in training:  69%|██████▊   | 322/469 [02:42<01:18,  1.86it/s]
# Epoch 5 in training:  69%|██████▉   | 323/469 [02:42<01:23,  1.75it/s]
# Epoch 5 in training:  69%|██████▉   | 324/469 [02:43<01:28,  1.63it/s]
# Epoch 5 in training:  69%|██████▉   | 325/469 [02:44<01:28,  1.63it/s]
# Epoch 5 in training:  70%|██████▉   | 326/469 [02:44<01:21,  1.76it/s]
# Epoch 5 in training:  70%|██████▉   | 327/469 [02:45<01:16,  1.85it/s]
# Epoch 5 in training:  70%|██████▉   | 328/469 [02:45<01:12,  1.95it/s]
# Epoch 5 in training:  70%|███████   | 329/469 [02:46<01:10,  1.99it/s]
# Epoch 5 in training:  70%|███████   | 330/469 [02:46<01:07,  2.04it/s]
# Epoch 5 in training:  71%|███████   | 331/469 [02:46<01:06,  2.06it/s]
# Epoch 5 in training:  71%|███████   | 332/469 [02:47<01:05,  2.10it/s]
# Epoch 5 in training:  71%|███████   | 333/469 [02:47<01:04,  2.11it/s]
# Epoch 5 in training:  71%|███████   | 334/469 [02:48<01:03,  2.13it/s]
# Epoch 5 in training:  71%|███████▏  | 335/469 [02:48<01:02,  2.14it/s]
# Epoch 5 in training:  72%|███████▏  | 336/469 [02:49<01:02,  2.12it/s]
# Epoch 5 in training:  72%|███████▏  | 337/469 [02:49<01:01,  2.15it/s]
# Epoch 5 in training:  72%|███████▏  | 338/469 [02:50<01:01,  2.14it/s]
# Epoch 5 in training:  72%|███████▏  | 339/469 [02:50<01:07,  1.92it/s]
# Epoch 5 in training:  72%|███████▏  | 340/469 [02:51<01:05,  1.97it/s]
# Epoch 5 in training:  73%|███████▎  | 341/469 [02:51<01:03,  2.02it/s]
# Epoch 5 in training:  73%|███████▎  | 342/469 [02:52<01:01,  2.05it/s]
# Epoch 5 in training:  73%|███████▎  | 343/469 [02:52<01:00,  2.08it/s]
# Epoch 5 in training:  73%|███████▎  | 344/469 [02:53<01:00,  2.08it/s]
# Epoch 5 in training:  74%|███████▎  | 345/469 [02:53<00:59,  2.10it/s]
# Epoch 5 in training:  74%|███████▍  | 346/469 [02:54<01:03,  1.95it/s]
# Epoch 5 in training:  74%|███████▍  | 347/469 [02:54<01:08,  1.79it/s]
# Epoch 5 in training:  74%|███████▍  | 348/469 [02:55<01:11,  1.69it/s]
# Epoch 5 in training:  74%|███████▍  | 349/469 [02:56<01:16,  1.57it/s]
# Epoch 5 in training:  75%|███████▍  | 350/469 [02:56<01:09,  1.71it/s]
# Epoch 5 in training:  75%|███████▍  | 351/469 [02:57<01:04,  1.82it/s]
# Epoch 5 in training:  75%|███████▌  | 352/469 [02:57<01:01,  1.91it/s]
# Epoch 5 in training:  75%|███████▌  | 353/469 [02:58<00:58,  1.97it/s]
# Epoch 5 in training:  75%|███████▌  | 354/469 [02:58<00:56,  2.03it/s]
# Epoch 5 in training:  76%|███████▌  | 355/469 [02:59<00:55,  2.07it/s]
# Epoch 5 in training:  76%|███████▌  | 356/469 [02:59<00:54,  2.08it/s]
# Epoch 5 in training:  76%|███████▌  | 357/469 [03:00<00:53,  2.11it/s]
# Epoch 5 in training:  76%|███████▋  | 358/469 [03:00<00:52,  2.11it/s]
# Epoch 5 in training:  77%|███████▋  | 359/469 [03:01<00:51,  2.13it/s]
# Epoch 5 in training:  77%|███████▋  | 360/469 [03:01<00:51,  2.13it/s]
# Epoch 5 in training:  77%|███████▋  | 361/469 [03:01<00:50,  2.14it/s]
# Epoch 5 in training:  77%|███████▋  | 362/469 [03:02<00:49,  2.15it/s]
# Epoch 5 in training:  77%|███████▋  | 363/469 [03:02<00:49,  2.14it/s]
# Epoch 5 in training:  78%|███████▊  | 364/469 [03:03<00:49,  2.13it/s]
# Epoch 5 in training:  78%|███████▊  | 365/469 [03:03<00:48,  2.14it/s]
# Epoch 5 in training:  78%|███████▊  | 366/469 [03:04<00:47,  2.15it/s]
# Epoch 5 in training:  78%|███████▊  | 367/469 [03:04<00:47,  2.15it/s]
# Epoch 5 in training:  78%|███████▊  | 368/469 [03:05<00:46,  2.15it/s]
# Epoch 5 in training:  79%|███████▊  | 369/469 [03:05<00:46,  2.15it/s]
# Epoch 5 in training:  79%|███████▉  | 370/469 [03:06<00:46,  2.15it/s]
# Epoch 5 in training:  79%|███████▉  | 371/469 [03:06<00:50,  1.95it/s]
# Epoch 5 in training:  79%|███████▉  | 372/469 [03:07<00:53,  1.80it/s]
# Epoch 5 in training:  80%|███████▉  | 373/469 [03:08<00:56,  1.68it/s]
# Epoch 5 in training:  80%|███████▉  | 374/469 [03:08<01:00,  1.58it/s]
# Epoch 5 in training:  80%|███████▉  | 375/469 [03:09<00:54,  1.72it/s]
# Epoch 5 in training:  80%|████████  | 376/469 [03:09<00:51,  1.81it/s]
# Epoch 5 in training:  80%|████████  | 377/469 [03:10<00:48,  1.91it/s]
# Epoch 5 in training:  81%|████████  | 378/469 [03:10<00:46,  1.97it/s]
# Epoch 5 in training:  81%|████████  | 379/469 [03:11<00:44,  2.03it/s]
# Epoch 5 in training:  81%|████████  | 380/469 [03:11<00:43,  2.06it/s]
# Epoch 5 in training:  81%|████████  | 381/469 [03:12<00:42,  2.08it/s]
# Epoch 5 in training:  81%|████████▏ | 382/469 [03:12<00:41,  2.11it/s]
# Epoch 5 in training:  82%|████████▏ | 383/469 [03:13<00:40,  2.12it/s]
# Epoch 5 in training:  82%|████████▏ | 384/469 [03:13<00:39,  2.14it/s]
# Epoch 5 in training:  82%|████████▏ | 385/469 [03:13<00:39,  2.12it/s]
# Epoch 5 in training:  82%|████████▏ | 386/469 [03:14<00:39,  2.13it/s]
# Epoch 5 in training:  83%|████████▎ | 387/469 [03:14<00:38,  2.13it/s]
# Epoch 5 in training:  83%|████████▎ | 388/469 [03:15<00:37,  2.14it/s]
# Epoch 5 in training:  83%|████████▎ | 389/469 [03:15<00:37,  2.12it/s]
# Epoch 5 in training:  83%|████████▎ | 390/469 [03:16<00:36,  2.15it/s]
# Epoch 5 in training:  83%|████████▎ | 391/469 [03:16<00:36,  2.16it/s]
# Epoch 5 in training:  84%|████████▎ | 392/469 [03:17<00:35,  2.15it/s]
# Epoch 5 in training:  84%|████████▍ | 393/469 [03:17<00:35,  2.16it/s]
# Epoch 5 in training:  84%|████████▍ | 394/469 [03:18<00:35,  2.14it/s]
# Epoch 5 in training:  84%|████████▍ | 395/469 [03:18<00:34,  2.14it/s]
# Epoch 5 in training:  84%|████████▍ | 396/469 [03:19<00:38,  1.92it/s]
# Epoch 5 in training:  85%|████████▍ | 397/469 [03:19<00:40,  1.76it/s]
# Epoch 5 in training:  85%|████████▍ | 398/469 [03:20<00:42,  1.66it/s]
# Epoch 5 in training:  85%|████████▌ | 399/469 [03:21<00:44,  1.59it/s]
# Epoch 5 in training:  85%|████████▌ | 400/469 [03:21<00:39,  1.73it/s]
# Epoch 5 in training:  86%|████████▌ | 401/469 [03:22<00:37,  1.83it/s]
# Epoch 5 in training:  86%|████████▌ | 402/469 [03:22<00:34,  1.92it/s]
# Epoch 5 in training:  86%|████████▌ | 403/469 [03:23<00:33,  1.98it/s]
# Epoch 5 in training:  86%|████████▌ | 404/469 [03:23<00:31,  2.03it/s]
# Epoch 5 in training:  86%|████████▋ | 405/469 [03:24<00:31,  2.06it/s]
# Epoch 5 in training:  87%|████████▋ | 406/469 [03:24<00:30,  2.09it/s]
# Epoch 5 in training:  87%|████████▋ | 407/469 [03:25<00:29,  2.12it/s]
# Epoch 5 in training:  87%|████████▋ | 408/469 [03:25<00:28,  2.13it/s]
# Epoch 5 in training:  87%|████████▋ | 409/469 [03:25<00:27,  2.16it/s]
# Epoch 5 in training:  87%|████████▋ | 410/469 [03:26<00:27,  2.15it/s]
# Epoch 5 in training:  88%|████████▊ | 411/469 [03:26<00:26,  2.16it/s]
# Epoch 5 in training:  88%|████████▊ | 412/469 [03:27<00:26,  2.16it/s]
# Epoch 5 in training:  88%|████████▊ | 413/469 [03:27<00:25,  2.16it/s]
# Epoch 5 in training:  88%|████████▊ | 414/469 [03:28<00:25,  2.15it/s]
# Epoch 5 in training:  88%|████████▊ | 415/469 [03:28<00:25,  2.16it/s]
# Epoch 5 in training:  89%|████████▊ | 416/469 [03:29<00:24,  2.13it/s]
# Epoch 5 in training:  89%|████████▉ | 417/469 [03:29<00:24,  2.15it/s]
# Epoch 5 in training:  89%|████████▉ | 418/469 [03:30<00:23,  2.16it/s]
# Epoch 5 in training:  89%|████████▉ | 419/469 [03:30<00:23,  2.14it/s]
# Epoch 5 in training:  90%|████████▉ | 420/469 [03:31<00:22,  2.15it/s]
# Epoch 5 in training:  90%|████████▉ | 421/469 [03:31<00:24,  1.92it/s]
# Epoch 5 in training:  90%|████████▉ | 422/469 [03:32<00:26,  1.76it/s]
# Epoch 5 in training:  90%|█████████ | 423/469 [03:33<00:27,  1.66it/s]
# Epoch 5 in training:  90%|█████████ | 424/469 [03:33<00:28,  1.58it/s]
# Epoch 5 in training:  91%|█████████ | 425/469 [03:34<00:25,  1.73it/s]
# Epoch 5 in training:  91%|█████████ | 426/469 [03:34<00:23,  1.82it/s]
# Epoch 5 in training:  91%|█████████ | 427/469 [03:35<00:22,  1.90it/s]
# Epoch 5 in training:  91%|█████████▏| 428/469 [03:35<00:20,  1.97it/s]
# Epoch 5 in training:  91%|█████████▏| 429/469 [03:36<00:19,  2.02it/s]
# Epoch 5 in training:  92%|█████████▏| 430/469 [03:36<00:19,  2.05it/s]
# Epoch 5 in training:  92%|█████████▏| 431/469 [03:37<00:18,  2.08it/s]
# Epoch 5 in training:  92%|█████████▏| 432/469 [03:37<00:17,  2.08it/s]
# Epoch 5 in training:  92%|█████████▏| 433/469 [03:38<00:17,  2.11it/s]
# Epoch 5 in training:  93%|█████████▎| 434/469 [03:38<00:16,  2.12it/s]
# Epoch 5 in training:  93%|█████████▎| 435/469 [03:38<00:16,  2.10it/s]
# Epoch 5 in training:  93%|█████████▎| 436/469 [03:39<00:15,  2.12it/s]
# Epoch 5 in training:  93%|█████████▎| 437/469 [03:39<00:15,  2.11it/s]
# Epoch 5 in training:  93%|█████████▎| 438/469 [03:40<00:14,  2.14it/s]
# Epoch 5 in training:  94%|█████████▎| 439/469 [03:40<00:14,  2.13it/s]
# Epoch 5 in training:  94%|█████████▍| 440/469 [03:41<00:13,  2.13it/s]
# Epoch 5 in training:  94%|█████████▍| 441/469 [03:41<00:13,  2.13it/s]
# Epoch 5 in training:  94%|█████████▍| 442/469 [03:42<00:12,  2.14it/s]
# Epoch 5 in training:  94%|█████████▍| 443/469 [03:42<00:12,  2.14it/s]
# Epoch 5 in training:  95%|█████████▍| 444/469 [03:43<00:11,  2.15it/s]
# Epoch 5 in training:  95%|█████████▍| 445/469 [03:43<00:11,  2.15it/s]
# Epoch 5 in training:  95%|█████████▌| 446/469 [03:44<00:12,  1.90it/s]
# Epoch 5 in training:  95%|█████████▌| 447/469 [03:44<00:12,  1.74it/s]
# Epoch 5 in training:  96%|█████████▌| 448/469 [03:45<00:12,  1.64it/s]
# Epoch 5 in training:  96%|█████████▌| 449/469 [03:46<00:12,  1.61it/s]
# Epoch 5 in training:  96%|█████████▌| 450/469 [03:46<00:10,  1.75it/s]
# Epoch 5 in training:  96%|█████████▌| 451/469 [03:47<00:09,  1.85it/s]
# Epoch 5 in training:  96%|█████████▋| 452/469 [03:47<00:08,  1.94it/s]
# Epoch 5 in training:  97%|█████████▋| 453/469 [03:48<00:08,  1.99it/s]
# Epoch 5 in training:  97%|█████████▋| 454/469 [03:48<00:07,  2.04it/s]
# Epoch 5 in training:  97%|█████████▋| 455/469 [03:49<00:06,  2.06it/s]
# Epoch 5 in training:  97%|█████████▋| 456/469 [03:49<00:06,  2.09it/s]
# Epoch 5 in training:  97%|█████████▋| 457/469 [03:50<00:05,  2.10it/s]
# Epoch 5 in training:  98%|█████████▊| 458/469 [03:50<00:05,  2.11it/s]
# Epoch 5 in training:  98%|█████████▊| 459/469 [03:50<00:04,  2.10it/s]
# Epoch 5 in training:  98%|█████████▊| 460/469 [03:51<00:04,  2.12it/s]
# Epoch 5 in training:  98%|█████████▊| 461/469 [03:51<00:03,  2.13it/s]
# Epoch 5 in training:  99%|█████████▊| 462/469 [03:52<00:03,  2.13it/s]
# Epoch 5 in training:  99%|█████████▊| 463/469 [03:52<00:02,  2.15it/s]
# Epoch 5 in training:  99%|█████████▉| 464/469 [03:53<00:02,  2.13it/s]
# Epoch 5 in training:  99%|█████████▉| 465/469 [03:53<00:01,  2.14it/s]
# Epoch 5 in training:  99%|█████████▉| 466/469 [03:54<00:01,  2.13it/s]
# Epoch 5 in training: 100%|█████████▉| 467/469 [03:54<00:00,  2.15it/s]
# Epoch 5 in training: 100%|█████████▉| 468/469 [03:55<00:00,  2.13it/s]
# Epoch 5 in training: 100%|██████████| 469/469 [03:55<00:00,  2.28it/s]
# Training: 100%|██████████| 5/5 [19:39<00:00, 235.87s/it]
# Epoch 5/5 loss: 1.66
# Testing: 100%|██████████| 79/79 [00:20<00:00,  3.76it/s]
# Test loss: 1.64
# Test accuracy: 82.05%
